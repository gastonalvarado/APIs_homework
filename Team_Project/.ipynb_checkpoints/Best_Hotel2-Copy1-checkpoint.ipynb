# %%
# Import dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json 
import requests
import time
from citipy import citipy

# Import api key 
from api_keys import gkey

# %%
# Build base url for text search 
nearby_type = "lodging"
target_coordinates = '41.5048, -81.6857'
radius = 8046.72
target_search = 'hotel'

nearby_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

params = {"type" : nearby_type,
          'keyword' : target_search,
         "location" : target_coordinates,
          'radius': radius,
         "key" : gkey}

response = requests.get(nearby_url, params=params)
cleveland_nearby = response.json()

print(json.dumps(cleveland_nearby, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCJQEAABy4DpHy38GFg_5PPK3cS6QW-h_EsZ0xcaSE-pc8O9QXLS0RPYGe9iwiIsEAK2Qk7gx1tr15daxZKWrQU-JwLu77pPTwvjolY0htBK3mbn9ByszxXH5oPXRmh9VAa6PwL_WSJP7v7z8-HSQB8fO3WDNa2CbGcsIn8ZQVXLRXcyl8P7ItEqpBiX0f5g8u2d4gJxE7FzDY5_VreZbI7fxAEiT5imcDIA-KEvj39Z6kR1d3XBzWnRDljRTIJSTHmKH71TPIXUsMDxH3vcOzRurZNwi-W0_4rFnHotYKbZj3LJuoRJQ7X2uJrC3i2qH5HfqEriELTBEZ-5XSIrDqsHULiq5oxG3tUYPz0IozAAVehB3UkuQJtTtMswrn9wzRAlZfx7670rKYFrjR5MHM848RU2cSEAaQPAth-1HW06AGR6817CEaFCh3pGSA55Rf9ToYZTh9GptfsXlj",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5005708,
#                     "lng": -81.7041148
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50187337989272,
#                         "lng": -81.70285247010727
#                     },
#                     "southwest": {
#                         "lat": 41.49917372010728,
#                         "lng": -81.70555212989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2a074fb880ae8a4483f52aa2f53f4835c83e5bcd",
#             "name": "Aloft Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106926295935055455922/photos\">Aloft Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqqilTOwE-WJiCW-qM_NcksY893qQ8teEdV4A6_GBVfSoaN1UsljPwptAy6_gKbu2eNWtEP1qSguoXyL3uf-XJp1o2QTGra9pgV2744rXfz66TImRCerHZCjpaGD2GO2-EhAU_GpfYiX4DW5Irc9asumJGhS0Als6cZArdk04OEj-bvfnXn-tWw",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJ-V-1mmLwMIgRCNkQ5iY0w6w",
#             "plus_code": {
#                 "compound_code": "G72W+69 Cleveland, Ohio, USA",
#                 "global_code": "86HWG72W+69"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ-V-1mmLwMIgRCNkQ5iY0w6w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1061,
#             "vicinity": "1111 W 10th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4986106,
#                     "lng": -81.6944717
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50012227989272,
#                         "lng": -81.69334847010727
#                     },
#                     "southwest": {
#                         "lat": 41.49742262010728,
#                         "lng": -81.69604812989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "dc96131c3dfcbcb2ac7e13ed64d123ee87082ee6",
#             "name": "Renaissance Cleveland Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 423,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106505317315732722159/photos\">Renaissance Cleveland Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAzqU-OhHjnXq0ZtIMIzS-FpIclq2I0YtSuP5SUklgVjFS1yt2DfoZ7KxnK9aib5RMy87KAgiMdIZJqMvympLB9VmUrNYNsuAVYhh-P35kC3i_vKH50wecYKnlMBKBdNbTEhBecFUsLkh-OP0J8UhcDegqGhT68kLgKpa5GfqEC0WGN1GK5PqfBQ",
#                     "width": 610
#                 }
#             ],
#             "place_id": "ChIJQdJiRX7wMIgRMHYixWs56JQ",
#             "plus_code": {
#                 "compound_code": "F8X4+C6 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X4+C6"
#             },
#             "rating": 4.1,
#             "reference": "ChIJQdJiRX7wMIgRMHYixWs56JQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1093,
#             "vicinity": "24 Public Square, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.49978790000001,
#                     "lng": -81.6858092
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50109112989273,
#                         "lng": -81.68468377010727
#                     },
#                     "southwest": {
#                         "lat": 41.49839147010729,
#                         "lng": -81.68738342989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "229a6b662cbc7e805641a48c703812fe77fb5023",
#             "name": "Metropolitan at the 9, Autograph Collection",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1066,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107721496052099022707/photos\">Metropolitan at the 9</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4Za7u7buDW6HYS8L57MtqbspO4Qhg4ULi3tx9LK39uP52micGmXrqkMwcOOc-C7_rINfX3SYXVmazPL8SfQbNoOZT1Ml8PWFeiliHa61ql5ma0ydGwmTQBjGOKzoDrjZEhAE37ZWaFQmQHevsKadL_JVGhTcHIKDABhxy1eJ7Bi4bn7RBmAgow",
#                     "width": 1599
#                 }
#             ],
#             "place_id": "ChIJE6DsqoD6MIgRheks77AlZ9w",
#             "plus_code": {
#                 "compound_code": "F8X7+WM Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X7+WM"
#             },
#             "rating": 4.5,
#             "reference": "ChIJE6DsqoD6MIgRheks77AlZ9w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 982,
#             "vicinity": "2017 E 9th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5008156,
#                     "lng": -81.6129579
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50224942989272,
#                         "lng": -81.61160032010727
#                     },
#                     "southwest": {
#                         "lat": 41.49954977010728,
#                         "lng": -81.61429997989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9eecfc862291acc94e516d8f2525ae868f45503c",
#             "name": "The Tudor Arms Hotel Cleveland - a DoubleTree by Hilton",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2015,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116657368107723201746/photos\">DoubleTree by Hilton - The Tudor Arms Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHD2f_J713fiOLpCefViGtkK59LCCCto5HHtCBaIwcFcRbX6Sck3dzm8Ci95d4Q95osmQPJBq7sOosIfsi02k7QQgQAlJ3rxhHUwx_zi3llREKApL4lHb1S7rlkOXYLInEhBYZeOXKoiUsRz_t5aJrKtzGhSXNk2RCtUuqmPWwj5BRejX4Wo4yw",
#                     "width": 1606
#                 }
#             ],
#             "place_id": "ChIJM5WTlIT7MIgRZXbXABw3OQw",
#             "plus_code": {
#                 "compound_code": "G92P+8R Cleveland, Ohio, USA",
#                 "global_code": "86HWG92P+8R"
#             },
#             "rating": 4.3,
#             "reference": "ChIJM5WTlIT7MIgRZXbXABw3OQw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 870,
#             "vicinity": "10660 Carnegie Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5001855,
#                     "lng": -81.688767
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50146397989272,
#                         "lng": -81.68740352010728
#                     },
#                     "southwest": {
#                         "lat": 41.49876432010728,
#                         "lng": -81.69010317989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "540b9cccc650b7e2f2219b63c22ec88b3291f43e",
#             "name": "Holiday Inn Express Cleveland Downtown",
#             "photos": [
#                 {
#                     "height": 1371,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100565948717289391741/photos\">Holiday Inn Express</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwvpB3dfO7Pv4hqi0NfUPkr8NfoJZdPcRvW4EMTS50zUzJj1VEXCgAvn-ZxRpeilLOG11PIv2PAfCt19011LwhT7F81QLBo5iBnFjMaw0TOoya5mpbZ43eJvw_mYhQ5p8EhD4m4iNA3l6dIS7iqeJJriAGhRg0YIEYS_c8e0PbNrTGhnkG8VJdA",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ8b9IeID6MIgRg7cfACiPh8I",
#             "plus_code": {
#                 "compound_code": "G826+3F Cleveland, Ohio, USA",
#                 "global_code": "86HWG826+3F"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ8b9IeID6MIgRg7cfACiPh8I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 912,
#             "vicinity": "629 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.50701,
#                     "lng": -81.6901721
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50844367989272,
#                         "lng": -81.68864007010728
#                     },
#                     "southwest": {
#                         "lat": 41.50574402010728,
#                         "lng": -81.69133972989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4d26de88917ca4040fe681a1b1d04cfd3a9b5b6d",
#             "name": "DoubleTree by Hilton Hotel Cleveland Downtown - Lakeside",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101740676124498109606/photos\">Hunter Lowrey</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAv1m6DsvLoTMgk5PjKyS7T_OqH7M-6Gd1Stg39eTnWn_02PQI2LJeat275WSoKCaLci4tu3AoJ1FpeL48cIDCLlF2RiKcHmh-cgH69HJonDUum0j0tWKwTrwfFZbs8rVhEhA9wgeYD2ivMZB6iDgJ7i2RGhRCo_v2Il0YpPeRwkW8T8Lofejz6g",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJkyQK63j6MIgR3WshTHAP94Q",
#             "plus_code": {
#                 "compound_code": "G845+RW Cleveland, Ohio, USA",
#                 "global_code": "86HWG845+RW"
#             },
#             "rating": 4.1,
#             "reference": "ChIJkyQK63j6MIgR3WshTHAP94Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1508,
#             "vicinity": "1111 Lakeside Ave E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030718,
#                     "lng": -81.6956723
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50416817989272,
#                         "lng": -81.69461932010728
#                     },
#                     "southwest": {
#                         "lat": 41.50146852010727,
#                         "lng": -81.69731897989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d48d9c2e557d51fde5c5bbe6879cd47a60303228",
#             "name": "Hilton Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4457,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110966001620855182613/photos\">Hilton Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8Ok8bST_29-ALFPXwTWH8etkc9LRt0BCR8pj_9HsRGFC_iAmJ3X11927bpkqG-lUd0a2AJMfAsf-YN-mZ3SoZc_9Nsvpgqzv3iAXEj8WYmhgeTbZvdg5CUdXWzsgNlkvEhC-VeWs6WZauvh5IbV65dw9GhRixkRC9h7LjdsvMqwM4Btqv7TTSw",
#                     "width": 6447
#                 }
#             ],
#             "place_id": "ChIJ9WAy2YDwMIgRqgktebGbYoM",
#             "plus_code": {
#                 "compound_code": "G833+6P Cleveland, Ohio, USA",
#                 "global_code": "86HWG833+6P"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ9WAy2YDwMIgRqgktebGbYoM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2149,
#             "vicinity": "100 Lakeside Ave E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5079608,
#                     "lng": -81.6052619
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50934832989272,
#                         "lng": -81.60406792010728
#                     },
#                     "southwest": {
#                         "lat": 41.50664867010727,
#                         "lng": -81.60676757989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "236612f588346362ba4d3eab4e2cac30d0af9cf2",
#             "name": "Courtyard by Marriott Cleveland University Circle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 423,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108302543331357230635/photos\">Courtyard Cleveland University Circle</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAuRzJpRblKi8FtMlLj1NtY8wSFTRdN2H0dUDIhytPXAptcK_m9IDjZl6VqRxz_TxP4qdNa7uj43osYCa8qd6kBYpaCB8VqqIRMg7IAdBdQ6Ih2cdNGXSJ5suk_lBJGRxkEhA_i-UqB9L1gZ5YwxaYuDidGhSezU6O9nnIm4yZ2Z3BPgvSuskyNQ",
#                     "width": 610
#                 }
#             ],
#             "place_id": "ChIJ0bg0mIn7MIgRdLO0rIQ4ndc",
#             "plus_code": {
#                 "compound_code": "G95V+5V Cleveland, Ohio, USA",
#                 "global_code": "86HWG95V+5V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ0bg0mIn7MIgRdLO0rIQ4ndc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 451,
#             "vicinity": "2021 Cornell Rd, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4961516,
#                     "lng": -81.6811465
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49760042989271,
#                         "lng": -81.67985862010727
#                     },
#                     "southwest": {
#                         "lat": 41.49490077010727,
#                         "lng": -81.68255827989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a96955fb5b1af20e6895a339263aa8e6aa0e673a",
#             "name": "Hilton Garden Inn Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108878919135820969416/photos\">Bobb Banar</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAE4sz_GMTGxWg_Y4ocNJ1maxCCgUfuOLBGEplJssE9NBRygjkWrRSPPRm7f3VgxIzCZMFN_ZC7JsoKchCpp5RkUnxeBDFqgeZ-77YHYAZZ4_wigJSGmAZFdmqnu7PlNTvEhBw6QyOasoyffDPU8075CQvGhQbcwebyAFsnaILGV2PsBZs2tKnqQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJtxcBOYb6MIgRW5MU3e2Lqew",
#             "plus_code": {
#                 "compound_code": "F8W9+FG Cleveland, Ohio, USA",
#                 "global_code": "86HWF8W9+FG"
#             },
#             "rating": 4.1,
#             "reference": "ChIJtxcBOYb6MIgRW5MU3e2Lqew",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1091,
#             "vicinity": "1100 Carnegie Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5016194,
#                     "lng": -81.6939388
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50299827989272,
#                         "lng": -81.69242667010728
#                     },
#                     "southwest": {
#                         "lat": 41.50029862010727,
#                         "lng": -81.69512632989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a08ed261be98ed49ff47fa4641fe8050fe97d8f2",
#             "name": "Cleveland Marriott Downtown at Key Tower",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 450,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111514528923731131288/photos\">Cleveland Marriott Downtown at Key Center</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5bQ4eMuaujNHyARj3M8h01XK6f1YIxlYZOck-zq0z6zz6yu85hZ-xZmeyMeIsj2qWbljnbxk9jnLJdOLGTGDz25iK0EnyI_u0AgbqjrESh1NDQjo1jz9uQOMG61TdbjTEhAZuQ3w1YlAlQEaaSKg65FYGhRs7cmFZxLVq7xrYAohlS9az4CZ2g",
#                     "width": 450
#                 }
#             ],
#             "place_id": "ChIJlzqOKX7wMIgRcG1mp3KKt8s",
#             "plus_code": {
#                 "compound_code": "G824+JC Cleveland, Ohio, USA",
#                 "global_code": "86HWG824+JC"
#             },
#             "rating": 4.3,
#             "reference": "ChIJlzqOKX7wMIgRcG1mp3KKt8s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1379,
#             "vicinity": "1360 W Mall Dr, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5021743,
#                     "lng": -81.69196860000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50371732989272,
#                         "lng": -81.69032442010729
#                     },
#                     "southwest": {
#                         "lat": 41.50101767010727,
#                         "lng": -81.69302407989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "cc1b9ed4c9c88db7f736792a02ba229ea1b367a7",
#             "name": "Drury Plaza Hotel Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4912,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102180379553984288471/photos\">Drury Plaza Hotel Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADEgJ48rRtV4X-bInAmX7SJ5ITFEU5fV6wwGPiBdwNQmB26_VBCnmVzD4MvUlE6WV5zRbj_6FIAPewlkcStWwmHOyr97VaIIlBw6c45PYr3alKxoqQAe6o76v9pmzLA_ZEhCHtWYczwYb6QkEf5pnD89CGhTjnr7gz4JuV6nAnn-eehAR2nWSzg",
#                     "width": 7360
#                 }
#             ],
#             "place_id": "ChIJz9VrMIDwMIgRU4dHrxBVI1k",
#             "plus_code": {
#                 "compound_code": "G825+V6 Cleveland, Ohio, USA",
#                 "global_code": "86HWG825+V6"
#             },
#             "rating": 4.6,
#             "reference": "ChIJz9VrMIDwMIgRU4dHrxBVI1k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1056,
#             "vicinity": "1380 E 6th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5037247,
#                     "lng": -81.69141259999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50490242989272,
#                         "lng": -81.68990442010727
#                     },
#                     "southwest": {
#                         "lat": 41.50220277010727,
#                         "lng": -81.6926040798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4f357118ef16ab4d8c934f5f662411262d2af189",
#             "name": "The Westin Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 450,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114015324217175192756/photos\">The Westin Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFGwqis6pxmfETKHLtQfOLS9WJKSGFnYSqMxf7bOGz6epuaheeDysc-IMkCRJfgghc2EyQQutIRKX0E2PSUzrC0dtRJM_oQdFb_BugaL2ahViD1teXtrjH7WyRhMg3LMLEhAIAlJxXa6BvJN-u15Z5JVXGhSQNuzNsgT7yEkG5z4i2i3BtfWkRg",
#                     "width": 450
#                 }
#             ],
#             "place_id": "ChIJjQ5B2YHwMIgRjNnpAsJKuBg",
#             "plus_code": {
#                 "compound_code": "G835+FC Cleveland, Ohio, USA",
#                 "global_code": "86HWG835+FC"
#             },
#             "rating": 4.4,
#             "reference": "ChIJjQ5B2YHwMIgRjNnpAsJKuBg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1722,
#             "vicinity": "777 St Clair Ave NE, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030267,
#                     "lng": -81.6263701
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50447727989272,
#                         "lng": -81.62502672010729
#                     },
#                     "southwest": {
#                         "lat": 41.50177762010728,
#                         "lng": -81.62772637989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "14a1bb7f036777d05955a99c3f2924d566f15b29",
#             "name": "Holiday Inn Cleveland Clinic",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101493648851036371042/photos\">Rick Adkins</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAT_qVsRZ7Jz9OmRC8UG1OD994MrNLeoJZRCWjnAeU4bs4yd5nnnVp3GcNyDnLD06Q7DyuayqXrnbrF_eQUTrsEiGDXL6KrliZbN4SlLXlVcnpR3FnnXDgnk6ktCc5llB8EhDsJHNm235mxPlQtZT--H7BGhQzCQ8bPQgWM-61Vewg37u_yyWXlQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJx3A1jKL7MIgRQwfzeK-X6Mc",
#             "plus_code": {
#                 "compound_code": "G93F+6F Cleveland, Ohio, USA",
#                 "global_code": "86HWG93F+6F"
#             },
#             "rating": 4.2,
#             "reference": "ChIJx3A1jKL7MIgRQwfzeK-X6Mc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 790,
#             "vicinity": "8650 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4987104,
#                     "lng": -81.6890219
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49994197989272,
#                         "lng": -81.68759502010728
#                     },
#                     "southwest": {
#                         "lat": 41.49724232010728,
#                         "lng": -81.69029467989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "18f9a2cf0ccbe3f72c8cf5529d734f3403026113",
#             "name": "Residence Inn by Marriott Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 597,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115701914032112458944/photos\">Residence Inn Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYItMhE3jRQern9wnYgcF6FUD7EAr5gh1FQUuC-IlMEPgfmaScgCfIScxXq5l_WeHljZSb3OpFx2qwp7vzU47HVXt8KvQmNEwOPYU3SPhrshNQ_QNaoPaWj6Ebmsp-1JmEhC6GDowaNWx3UQ9TuUrUXOmGhQqNz-4KBR42rrIJblwi7HSuH9m9g",
#                     "width": 598
#                 }
#             ],
#             "place_id": "ChIJY8UhA2L6MIgRjU4eiYtqbnM",
#             "plus_code": {
#                 "compound_code": "F8X6+F9 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X6+F9"
#             },
#             "rating": 4.4,
#             "reference": "ChIJY8UhA2L6MIgRjU4eiYtqbnM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 467,
#             "vicinity": "527 Prospect Ave E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.502438,
#                     "lng": -81.689041
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50374242989272,
#                         "lng": -81.68757202010728
#                     },
#                     "southwest": {
#                         "lat": 41.50104277010728,
#                         "lng": -81.69027167989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c5346f7cd1d5b797021f4d91e61c6e54aae1b52e",
#             "name": "Hampton Inn Cleveland-Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111748181403513024778/photos\">Hampton Inn Cleveland-Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYCdmtlCJHdHVDLd9pZkHXvmmaa5pKiaipvndeipz_aoXD85Y5tmIyktnuwWlNwfzodSVXrmi_vMxCDaebrYBXG1U2gkZYtFNYnPFm1OhkgkbvfmQLt420OC1akiJ46DoEhCvtuUfaI_Pi3MDQSKApdunGhQt0et8aomXQJEc29n-X43fhs93tw",
#                     "width": 1331
#                 }
#             ],
#             "place_id": "ChIJewgGqX_6MIgRVI5s1kAUzyk",
#             "plus_code": {
#                 "compound_code": "G826+X9 Cleveland, Ohio, USA",
#                 "global_code": "86HWG826+X9"
#             },
#             "rating": 4.2,
#             "reference": "ChIJewgGqX_6MIgRVI5s1kAUzyk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 887,
#             "vicinity": "1460 E 9th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5014493,
#                     "lng": -81.6193432
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50282682989273,
#                         "lng": -81.61799387010727
#                     },
#                     "southwest": {
#                         "lat": 41.50012717010728,
#                         "lng": -81.62069352989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f12462b0c447b43fa915521b3647d600fb3c3e80",
#             "name": "InterContinental Cleveland",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106627160959710507739/photos\">Greg Reese</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcBOJY8bw4hasT3NyovBpykZXpwnZJZlrncNfD8ytGlgPnyvkxgXQEbyzbIYqaOo_N5mQgIiYoIOfxEEsSnpKu_ZichrDZ_AYG9Ne-dwCx38QplvE5hSNXdkabxqvchsQEhDUEYN6LifmyKEmT-mqUILQGhQt6K9PMZNFjOPTQgQpwjfHFYzI-g",
#                     "width": 6000
#                 }
#             ],
#             "place_id": "ChIJm_rT55v7MIgRkVJ4n5CNiOE",
#             "plus_code": {
#                 "compound_code": "G92J+H7 Cleveland, Ohio, USA",
#                 "global_code": "86HWG92J+H7"
#             },
#             "rating": 4.5,
#             "reference": "ChIJm_rT55v7MIgRkVJ4n5CNiOE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 690,
#             "vicinity": "9801 Carnegie Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030649,
#                     "lng": -81.6252999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50435477989272,
#                         "lng": -81.62381397010726
#                     },
#                     "southwest": {
#                         "lat": 41.50165512010728,
#                         "lng": -81.62651362989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "16c4160012583af17b2d8b58cf86791f89c666a9",
#             "name": "InterContinental Suites Hotel Cleveland",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103453579842648476437/photos\">Sandeep Kulkarni</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjjlITg7doVm6oQGm-gei6Pb9Li4Jwean_TrA2VwHbAg3ZtxzEEojtvM6JsqL8G7_XJEwg1wufJfMFIkqfuwfyiwHdsd8P-Rzbc-vPX1mRXasqLJMDDrsiR8TB7swDohwEhDUcQst3jYh4uhnBBiyJM5CGhSOrDmivlbd7N1qdxymipF-DhwqyA",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJs9bne5j7MIgRK7gn3Ut37mE",
#             "plus_code": {
#                 "compound_code": "G93F+6V Cleveland, Ohio, USA",
#                 "global_code": "86HWG93F+6V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJs9bne5j7MIgRK7gn3Ut37mE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 427,
#             "vicinity": "8800 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4973165,
#                     "lng": -81.6944019
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49873277989272,
#                         "lng": -81.69304697010729
#                     },
#                     "southwest": {
#                         "lat": 41.49603312010728,
#                         "lng": -81.69574662989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e1b5c13f65d9a50ec78c8c478343c00b50b7362f",
#             "name": "The Ritz-Carlton, Cleveland",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 6565,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110629792372181435148/photos\">The Ritz-Carlton, Cleveland</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8pB9yHupjRE_xO2EQTTWBf31WAKz3tAkRFGUVHBQ_ZV6Qa8pF2tXaSvP2olPsLXTZ2-K6cVKeje4SgAlfgOMnRYec9yxu31F3ttLcqggfx98QDhjuLAhnJCslJmpZpmKEhDA720cKfDXe2FDkf1lLnBtGhTsAJcUom8M2zXD3yBqbXNOQdkQ_g",
#                     "width": 7944
#                 }
#             ],
#             "place_id": "ChIJ6fFs8X7wMIgR2muORRtGlpc",
#             "plus_code": {
#                 "compound_code": "F8W4+W6 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8W4+W6"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ6fFs8X7wMIgR2muORRtGlpc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 415,
#             "vicinity": "1515 W 3rd St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4894755,
#                     "lng": -81.7731469
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49101532989272,
#                         "lng": -81.77171747010728
#                     },
#                     "southwest": {
#                         "lat": 41.48831567010728,
#                         "lng": -81.77441712989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6891b62a9d1047bd7ce19b8a802b8991ea4b31a5",
#             "name": "Days Inn by Wyndham Cleveland Lakewood",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114602264570729086954/photos\">David Chudd</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAklxlwipUgx4xB0RljeZYPVvgOPb1_P8mDIpifXxPyF8hrjksoEVAWiClv8_GeVIh5kjXuN10ZzZUYH2_0oTfySD181odFWQPiGoVi_HbJ8J0HulZaF1xeoXkqZ_K-fNHEhDxfsfXDP3-bm1S35rQUBbPGhS9-3zO7oqdY_b43zvDuBrEJZEdEg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJuemwd4zxMIgRR3D4Z1ZgDsg",
#             "plus_code": {
#                 "compound_code": "F6QG+QP Lakewood, Ohio, USA",
#                 "global_code": "86HWF6QG+QP"
#             },
#             "rating": 2.7,
#             "reference": "ChIJuemwd4zxMIgRR3D4Z1ZgDsg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 413,
#             "vicinity": "12019 Lake Ave, Lakewood"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.499811,
#                     "lng": -81.686762
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50122937989272,
#                         "lng": -81.68527052010728
#                     },
#                     "southwest": {
#                         "lat": 41.49852972010728,
#                         "lng": -81.68797017989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "33add8e876328b7cac14a6bb53fb2ff1620b8fce",
#             "name": "Kimpton Schofield Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 900,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107956572111716772725/photos\">Darryl Smith</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxcm2NxAVcVa6gDTU4xz9OW7_6PlgQu0I62w3UdJcpUeBO3e8IcR5_otblgbfi9meAqEKIPgJd9Ax7Q0jpHP1jmLeHAZgJo2NiZKFSek7FF5Jh41_10s-oVPQjPJ2dISbEhAyPSQyFA-ZfLg6LGDSus8yGhSr-SEX2N4VDhcRAA6x30gL8HTjEQ",
#                     "width": 1200
#                 }
#             ],
#             "place_id": "ChIJowjHoID6MIgRYkqUBQC5bmk",
#             "plus_code": {
#                 "compound_code": "F8X7+W7 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X7+W7"
#             },
#             "rating": 4.5,
#             "reference": "ChIJowjHoID6MIgRYkqUBQC5bmk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 535,
#             "vicinity": "2000 E 9th St, Cleveland"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Show response url 
response.url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=lodging&keyword=hotel&location=41.5048%2C+-81.6857&radius=8046.72&key=AIzaSyA1yTwp7ia1h-TvWcYRc1mUAN1o4Pq713g'

# %%
# Create lists to hold all of our data points
address = []
lat = []
lng = []
name = []
place_id = []
rating = []
user_ratings_total = []
types = []

# Building lists 
for element in cleveland_nearby['results']:
    #address.append(element['formatted_address'])
    lat.append(element['geometry']['location']['lat'])
    lng.append(element['geometry']['location']['lng'])
    name.append(element['name'])
    place_id.append(element['place_id'])
    rating.append(element['rating'])
    user_ratings_total.append(element['user_ratings_total'])
    types.append(element['types'])
    
# Create first DataFrame for hotel data 
place_df = pd.DataFrame({'Name': name, 'Place_ID': place_id, 'Latitude': lat,
                         'Longitude': lng, 'Rating': rating, 'Total Reviews': user_ratings_total,
                         'Types': types})
place_df.head()
# Out:
#                                                 Name  \
# 0                           Aloft Cleveland Downtown
# 1                        Renaissance Cleveland Hotel
# 2        Metropolitan at the 9, Autograph Collection
# 3  The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 4             Holiday Inn Express Cleveland Downtown
#
#                       Place_ID   Latitude  Longitude  Rating  Total Reviews  \
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1061
# 1  ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1093
# 2  ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            982
# 3  ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            870
# 4  ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            912
#
#                                          Types
# 0  [lodging, point_of_interest, establishment]
# 1  [lodging, point_of_interest, establishment]
# 2  [lodging, point_of_interest, establishment]
# 3  [lodging, point_of_interest, establishment]
# 4  [lodging, point_of_interest, establishment]

# %%
# Build base url for text search 
nearby_type = "lodging"
target_coordinates = '41.5048, -81.6857'
radius = 1609
target_search = 'hotel'

nearby_url2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=CrQCJQEAAKxS_9LTBO92bf0-ubPGv5GGv_UxIxph5MTsbpfy1bgyOLfb8X78HIZrD148N2DgpUlbflJ0HxjLCIB97a4sRq5AxQbWhZDPccucDkVBXWKRBIxLvN2DhJTn1vz0_GWXnAL9WVEbUyGaqJCsZcW_E1SgQSpcI3jHz62VSIExTXTz3ngcLKDPeMX4YAR1tZ_py_-LffKugMcMB3z0G529KpAOqNKCrDB4b6zuXOD4ZfZkPKJza0R6wjspqlgXqGkpYZmQEqcT92BLJmOOtb9mynpPtaW9hbqP_AvomdvhOGG8CPH2cZLvaBooac2ksAIzLz4NLKbiy_u-S2OYgLrzxU9ZkIqufjFWmsXhavpOvHLuNsl65IRwMVZhEYtZ0vKzzrEnYTnMYAZiyBUnIItmCc4SEFafsJUJOMvFZvGe6M9rtmMaFD8If96ikOXeTzkel5n0P7EMRIFZ"

params = {"type" : nearby_type,
          'keyword' : target_search,
         "location" : target_coordinates,
          'radius': radius,
         "key" : gkey}

response = requests.get(nearby_url2, params=params)
cleveland_nearby2 = response.json()

print(json.dumps(cleveland_nearby2, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CtQDxQEAAILx6M7oKiDDyOCIB0yS7DyZTVP5Hriih_75mFAAR5F0fJB95hQSwZRcwHhlzsoEPaIGgxHFT5AZpwaGuc_0k75QH48CqczdqzU2QhwCGwxOb2A1bbjMx6zzuK7eywdO_xA5SjLQhcFaZIkCcL82Bih7GTK0e_g1b_tcf3pxRqwlhEhc7QzaPjRPJEZf0Yfq5gVKPMxt-Y3hqZTITtJvknFE7i9zBGHl9T2di4X4HBrHkkV7w8xYOThhJFSYpBOe35CQJSx1YG5a0FYeuYm9nU4CT7ZMO1cj9EYTHOQ5IboMYv5eehFxWVtZQYYXNi1QlacmKN1MUJZ1CtUk1AJs6d14EidPCSvdZgBS9g-7pVEj-NPD0ynvWcp0N3tss_-n1z7PFnITC2kBPIvHkcbh18ZLYQyqpQ7EgX7XZuHsldM0yfMDbBOi2cq43OnLw_Aj1sjc-XbgS5ngYH9fOvxo6OCsgQmjsDupca-zI3-u-9jzCKoKN1hlu1CyNZycbxSRbxDJUDbiQKB0GdoY9Cp_iyI9Z-u676zzsfRdEF0x9jGlLen72HZfuZzGH19xLG3TMDaKgF0AskuGOjOF_wKjp6Qqsect_E708iXochRqBZfDEhC-Uiq3vct8fdZLFzCdb3bYGhRNYa7ZMaluNoC2us2TG9C76Hrzag",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030267,
#                     "lng": -81.6263701
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50447727989272,
#                         "lng": -81.62502672010729
#                     },
#                     "southwest": {
#                         "lat": 41.50177762010728,
#                         "lng": -81.62772637989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "14a1bb7f036777d05955a99c3f2924d566f15b29",
#             "name": "Holiday Inn Cleveland Clinic",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101493648851036371042/photos\">Rick Adkins</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAZoS5vKg6C64UGj9GKslec31CGQHyI-sChUpqUdyKqaGx1UDun7d7hfscSUAvsOa7m6-YiKptUs7nvaId4iBWIuOIyosZZK0P-gwg7tRbes0u90slYukPVev3Fp3cx7vpEhBJYWJ8h0nImPQGWQybzRRAGhT25TBa6lrl91veIG5v4sFpN_jIFQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJx3A1jKL7MIgRQwfzeK-X6Mc",
#             "plus_code": {
#                 "compound_code": "G93F+6F Cleveland, Ohio, USA",
#                 "global_code": "86HWG93F+6F"
#             },
#             "rating": 4.2,
#             "reference": "ChIJx3A1jKL7MIgRQwfzeK-X6Mc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 790,
#             "vicinity": "8650 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.499789,
#                     "lng": -81.6908413
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50172952989273,
#                         "lng": -81.68982942010727
#                     },
#                     "southwest": {
#                         "lat": 41.49902987010728,
#                         "lng": -81.69252907989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "dd4c2987f439a07804cb964f5b21237bfd127e2a",
#             "name": "Hyatt Regency Cleveland At The Arcade",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2236,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106943646533223603020/photos\">Hyatt Regency Cleveland At The Arcade</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaAFgwBUzAIZ8UFMDIjOLGlOrQCPeCD__cuUhvS1M88sHONC2eXLbKG500sy_kcwHAyr0EhAXFMCmo4o2ugU0UvVYmd8yB_AiC3tjpgXLjqKHKnTLpVsHlTEzZV-AeEIqEhB_hS7PH9AiKZGZgpPB0owXGhSTCgLIduPzpYRsHeodEtdzVZJxyA",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJU79i-X_6MIgRgAo4Y1a36zw",
#             "plus_code": {
#                 "compound_code": "F8X5+WM Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X5+WM"
#             },
#             "rating": 4.4,
#             "reference": "ChIJU79i-X_6MIgRgAo4Y1a36zw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1300,
#             "vicinity": "420 Superior Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030649,
#                     "lng": -81.6252999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50435477989272,
#                         "lng": -81.62381397010726
#                     },
#                     "southwest": {
#                         "lat": 41.50165512010728,
#                         "lng": -81.62651362989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "16c4160012583af17b2d8b58cf86791f89c666a9",
#             "name": "InterContinental Suites Hotel Cleveland",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103453579842648476437/photos\">Sandeep Kulkarni</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA_oY7X_a01R4AbeaAT1VLGtTybLOUbGYVmnewIuvBO1CZy03OYPEAjsViMwU8S4t23EWiLIP2xXpIzPp3bjD8oYrVnWZuS9-VQE5LzSGt4fa74FTCxGJfqQd9A0kVgnN5EhCTxfUub6w43ma-_R0RIpUeGhSqh79-BHQoT3JcfMs7OfjqXknHfg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJs9bne5j7MIgRK7gn3Ut37mE",
#             "plus_code": {
#                 "compound_code": "G93F+6V Cleveland, Ohio, USA",
#                 "global_code": "86HWG93F+6V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJs9bne5j7MIgRK7gn3Ut37mE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 427,
#             "vicinity": "8800 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5026862,
#                     "lng": -81.6619004
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50422637989272,
#                         "lng": -81.66057517010728
#                     },
#                     "southwest": {
#                         "lat": 41.50152672010728,
#                         "lng": -81.66327482989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "85b94cf3e0ba782387ccfcb044f4497e86453417",
#             "name": "University Hotel and Suites",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118191734931864390259/photos\">daniel biondo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA1hF5YbiTXw3fKpahhPqefOdXKkA-s3Z7z520JjRHIHfcXyxcBV_ktInDTMSqFAJJEBzC8c6HHjTMVpFvSmNH-vygyh52Qja_3nfm2RpztEzCVovmjF42_wVjmGTbQ5tpEhAQhqCK_90joj43y7LpcmI3GhQQLCzZ-9Rg25Wa_sGHnyQCE0lu5w",
#                     "width": 2268
#                 }
#             ],
#             "place_id": "ChIJc3VeZFn6MIgRDfZmd6I8NQo",
#             "plus_code": {
#                 "compound_code": "G83Q+36 Cleveland, Ohio, USA",
#                 "global_code": "86HWG83Q+36"
#             },
#             "rating": 2.8,
#             "reference": "ChIJc3VeZFn6MIgRDfZmd6I8NQo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 591,
#             "vicinity": "3614 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5109436,
#                     "lng": -81.607877
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.51214097989272,
#                         "lng": -81.60672232010728
#                     },
#                     "southwest": {
#                         "lat": 41.50944132010728,
#                         "lng": -81.60942197989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e17ae10b89220409598b309cf1a927c1c8950b13",
#             "name": "Glidden House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107940753662136485035/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYON3-ZsXGCIN5SJzTI09p6kEEhUPRkh3N8lpy8NVAsIg5M3qfwMzuvjIHc5T6EwsSSeYdqr_ik11BK0MehngHbuShxxetXZ-B0pDf_DuHHd0eAAA20KZFhY2Ej5D3QFSEhC-3tMZcQW6TLJQQ91g3xf7GhQzhd646kl0Umw2CY30wDoMCpRCjQ",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJv1Qamov7MIgRAUiBRQkU2-A",
#             "plus_code": {
#                 "compound_code": "G96R+9R Cleveland, Ohio, USA",
#                 "global_code": "86HWG96R+9R"
#             },
#             "rating": 4.6,
#             "reference": "ChIJv1Qamov7MIgRAUiBRQkU2-A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 340,
#             "vicinity": "1901 Ford Dr, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5004615,
#                     "lng": -81.6833738
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50190117989273,
#                         "lng": -81.68204442010727
#                     },
#                     "southwest": {
#                         "lat": 41.49920152010728,
#                         "lng": -81.68474407989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "287b03d00231da73bac1cad7a805e09a2d0e795d",
#             "name": "Crowne Plaza Cleveland at Playhouse Square",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110636021344697030653/photos\">Brian Johnson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATYY2neh5CeIOg32laOLS1BNp2xwGBCiNRiGpC3bb241ek3HwR4QosLmI0MSYonlAJ5OkV7QZviILIsG4sM3lIco3HI4P4P-EMJvXeWzMznxHBvZrtmi8DPyZOjl0Ni_qEhDvGQfd3IYDjL1IbOAHL02kGhSTwcF4qO4EjxPerwFxuLIGssvfIg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJp252m336MIgRX9QDJIGuKFU",
#             "plus_code": {
#                 "compound_code": "G828+5M Cleveland, Ohio, USA",
#                 "global_code": "86HWG828+5M"
#             },
#             "rating": 4.2,
#             "reference": "ChIJp252m336MIgRX9QDJIGuKFU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 509,
#             "vicinity": "1260 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.50066,
#                     "lng": -81.68475839999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50197592989272,
#                         "lng": -81.68339997010729
#                     },
#                     "southwest": {
#                         "lat": 41.49927627010728,
#                         "lng": -81.68609962989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4dc95366bb2c00b16be49d82acb7810baab6a67b",
#             "name": "Park Today",
#             "place_id": "ChIJp1rJ7n36MIgRwwpkpwISUWw",
#             "plus_code": {
#                 "compound_code": "G828+73 Cleveland, Ohio, USA",
#                 "global_code": "86HWG828+73"
#             },
#             "rating": 0,
#             "reference": "ChIJp1rJ7n36MIgRwwpkpwISUWw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "1127 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030197,
#                     "lng": -81.66613
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50422802989272,
#                         "lng": -81.66475757010727
#                     },
#                     "southwest": {
#                         "lat": 41.50152837010728,
#                         "lng": -81.6674572298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d3fbea6fb80cc8d2a08def4e7860c85ee318cc49",
#             "name": "catawba yacht club",
#             "place_id": "ChIJF2AFhF76MIgRil1XbzWM2ZM",
#             "plus_code": {
#                 "compound_code": "G83M+6G Cleveland, Ohio, USA",
#                 "global_code": "86HWG83M+6G"
#             },
#             "rating": 0,
#             "reference": "ChIJF2AFhF76MIgRil1XbzWM2ZM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "3121 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5085071,
#                     "lng": -81.67446369999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.51004162989272,
#                         "lng": -81.67324402010728
#                     },
#                     "southwest": {
#                         "lat": 41.50734197010728,
#                         "lng": -81.67594367989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c3fc2f51b41a420cb26f846150c02e20b9388742",
#             "name": "redspot",
#             "place_id": "ChIJDXyNBmb6MIgRvw-P0NGHHXo",
#             "plus_code": {
#                 "compound_code": "G85G+C6 Cleveland, Ohio, USA",
#                 "global_code": "86HWG85G+C6"
#             },
#             "rating": 0,
#             "reference": "ChIJDXyNBmb6MIgRvw-P0NGHHXo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "2400 Superior Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030718,
#                     "lng": -81.6956723
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50454197989273,
#                         "lng": -81.69443002010728
#                     },
#                     "southwest": {
#                         "lat": 41.50184232010729,
#                         "lng": -81.69712967989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e1cecb9fa307093a77c1f4ead901174768a84ce8",
#             "name": "Hilton",
#             "place_id": "ChIJn72y7Xj6MIgRRjyFgT8IMZk",
#             "plus_code": {
#                 "compound_code": "G833+6P Cleveland, Ohio, USA",
#                 "global_code": "86HWG833+6P"
#             },
#             "rating": 4.8,
#             "reference": "ChIJn72y7Xj6MIgRRjyFgT8IMZk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "100 Lakeside Ave E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5008836,
#                     "lng": -81.6784514
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50241417989272,
#                         "lng": -81.67705212010729
#                     },
#                     "southwest": {
#                         "lat": 41.49971452010728,
#                         "lng": -81.67975177989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "65f17f8a9863f74a0cca45c288af9db92b437872",
#             "name": "1800 Euclid Hospitality Group",
#             "place_id": "ChIJI23g52L6MIgR71RRKXfUJuw",
#             "plus_code": {
#                 "compound_code": "G82C+9J Cleveland, Ohio, USA",
#                 "global_code": "86HWG82C+9J"
#             },
#             "rating": 4.7,
#             "reference": "ChIJI23g52L6MIgR71RRKXfUJuw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "1800 Euclid Ave # 1, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4687294,
#                     "lng": -81.6873671
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.47007877989272,
#                         "lng": -81.68614082010728
#                     },
#                     "southwest": {
#                         "lat": 41.46737912010727,
#                         "lng": -81.68884047989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d2ec5a7f626349927d7de4538026cd802bc74678",
#             "name": "A Christmas Story House Loft Rental",
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117382712380336441981/photos\">Rex Mercer</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAVmZvl4DJe_qPdK5f27I_9bi33ff-mjTN9x3fFVObzLrY_rxgFK5qXZ2AisYy-kQI1a1Y-bug1WSAn9QVeVRSAoEYRRT5oFFABIMapeIlWCBJL9SOVZAehuuzePPMSU1zEhD4geVpgi2-fuHK5Ex6KWcZGhQuN63i-XxI1hUxcr1RepUnAmPssQ",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJVeZ366j6MIgRIVvD0qSYsh4",
#             "plus_code": {
#                 "compound_code": "F897+F3 Cleveland, Ohio, USA",
#                 "global_code": "86HWF897+F3"
#             },
#             "rating": 5,
#             "reference": "ChIJVeZ366j6MIgRIVvD0qSYsh4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "3159 W 11th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4923165,
#                     "lng": -81.5975297
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49353402989272,
#                         "lng": -81.59642642010728
#                     },
#                     "southwest": {
#                         "lat": 41.49083437010728,
#                         "lng": -81.59912607989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5a6797fc18e4d56070e19bcaaf9638e979574513",
#             "name": "hotels",
#             "place_id": "ChIJ3e-GwKj9MIgRXRcfIWWv1to",
#             "plus_code": {
#                 "compound_code": "FCR2+WX Cleveland, Ohio, USA",
#                 "global_code": "86HWFCR2+WX"
#             },
#             "rating": 0,
#             "reference": "ChIJ3e-GwKj9MIgRXRcfIWWv1to",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "12200 Fairhill Rd # B414, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.509068,
#                     "lng": -81.6731133
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.51061907989272,
#                         "lng": -81.67204497010727
#                     },
#                     "southwest": {
#                         "lat": 41.50791942010728,
#                         "lng": -81.67474462989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "34d363d6f48eac4ef2504f6f9fa62c1a199624fc",
#             "name": "Urban Design Suite",
#             "place_id": "ChIJa7UAmWj6MIgRySQrPk4BO_E",
#             "plus_code": {
#                 "compound_code": "G85G+JQ Cleveland, Ohio, USA",
#                 "global_code": "86HWG85G+JQ"
#             },
#             "rating": 0,
#             "reference": "ChIJa7UAmWj6MIgRySQrPk4BO_E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "2570 Superior Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4971659,
#                     "lng": -81.6940644
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49857627989272,
#                         "lng": -81.69271077010728
#                     },
#                     "southwest": {
#                         "lat": 41.49587662010728,
#                         "lng": -81.69541042989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "356c6a5e45bda77eb0d2d30c8c6156da18d62864",
#             "name": "Casino Hotel",
#             "place_id": "ChIJm1xx_rrxMIgRmUQR0Wpz_7o",
#             "plus_code": {
#                 "compound_code": "F8W4+V9 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8W4+V9"
#             },
#             "rating": 0,
#             "reference": "ChIJm1xx_rrxMIgRmUQR0Wpz_7o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "250 W Huron Rd, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.49932,
#                     "lng": -81.6943605
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50066982989272,
#                         "lng": -81.69301067010727
#                     },
#                     "southwest": {
#                         "lat": 41.49797017010727,
#                         "lng": -81.69571032989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "74880db63a8dbb78bb19df19726053527f2e2237",
#             "name": "USA",
#             "place_id": "ChIJq3GuHHjxMIgRVi6vJMesADI",
#             "plus_code": {
#                 "compound_code": "F8X4+P7 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X4+P7"
#             },
#             "rating": 0,
#             "reference": "ChIJq3GuHHjxMIgRVi6vJMesADI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5016031,
#                     "lng": -81.619175
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50287387989273,
#                         "lng": -81.61793067010727
#                     },
#                     "southwest": {
#                         "lat": 41.50017422010728,
#                         "lng": -81.62063032989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "495688a1178c154f4e798c8d8cbc5bceda0c0c16",
#             "name": "Alcazar Hotel",
#             "place_id": "ChIJ1TzoxJv7MIgRWiijLUrBJrE",
#             "plus_code": {
#                 "compound_code": "G92J+J8 Cleveland, Ohio, USA",
#                 "global_code": "86HWG92J+J8"
#             },
#             "rating": 0,
#             "reference": "ChIJ1TzoxJv7MIgRWiijLUrBJrE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "9801 Carnegie Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5059501,
#                     "lng": -81.6172965
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50729702989273,
#                         "lng": -81.61581612010727
#                     },
#                     "southwest": {
#                         "lat": 41.50459737010728,
#                         "lng": -81.61851577989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c8d0c7cc9d7914d642c6f0527b5cf053c658ea87",
#             "name": "Residence Inn",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107450849509407959993/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAD8zRYyt3bdy5R9obR5FnexV9HCzB0fwD9Qv-0xR5bAk0-yekJbrxr-8DqjCQUI0_iAfacqWOxjt56d2pqomZkFyQGQgQADIW4456D-I16aHsod4z59npHi1kDiZEVMCpEhAlFvYCrcjMlZJ5CYjaROAhGhQ-6DYJF7yJJ0Hss-soW-RKJxt4AA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJyU-ZYZD7MIgR0UzjaUGy5tM",
#             "plus_code": {
#                 "compound_code": "G94M+93 Cleveland, Ohio, USA",
#                 "global_code": "86HWG94M+93"
#             },
#             "rating": 3.7,
#             "reference": "ChIJyU-ZYZD7MIgR0UzjaUGy5tM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "1914 E 101st St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.49813959999999,
#                     "lng": -81.6876913
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49941797989272,
#                         "lng": -81.68627552010727
#                     },
#                     "southwest": {
#                         "lat": 41.49671832010728,
#                         "lng": -81.68897517989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f1af5c6d8c1effb6e85e8b3032ec294134bef685",
#             "name": "Hotel Cleveland Gateway",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJ6xhOyTP7MIgRG5i0LXBcqn8",
#             "plus_code": {
#                 "compound_code": "F8X6+7W Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X6+7W"
#             },
#             "rating": 0,
#             "reference": "ChIJ6xhOyTP7MIgRG5i0LXBcqn8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "651 Huron Rd E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4690375,
#                     "lng": -81.6873737
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.47032122989273,
#                         "lng": -81.68617222010727
#                     },
#                     "southwest": {
#                         "lat": 41.46762157010728,
#                         "lng": -81.68887187989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8edd3b78cdb0b2af5cdbf20ac36ec99e460010e2",
#             "name": "The Bumpus House",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107989028313692403462/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAc8cy6h_Q1VE-rZK18DBrdJV5U2NABSeLX8Ylqh2ndBH6le5P5dbS8hwP0yyZ0RwSGTK7PFo0EASKuLx4D54MfF3D92rWu9N902tox0Q-8g7WMMXZqWgZ3K_yxRXGcw8QEhDw6plXhBPcfuIHMJauCsWrGhSl25yhEvt95GMVFpGcUD4qzTk2OA",
#                     "width": 1357
#                 }
#             ],
#             "place_id": "ChIJIRHsk9j7MIgRaAv5LgVWd7Y",
#             "plus_code": {
#                 "compound_code": "F897+J3 Cleveland, Ohio, USA",
#                 "global_code": "86HWF897+J3"
#             },
#             "rating": 4.3,
#             "reference": "ChIJIRHsk9j7MIgRaAv5LgVWd7Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "3153 W 11th St, Cleveland"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Building lists 
for element in cleveland_nearby2['results']:
    lat.append(element['geometry']['location']['lat'])
    lng.append(element['geometry']['location']['lng'])
    name.append(element['name'])
    place_id.append(element['place_id'])
    rating.append(element['rating'])
    user_ratings_total.append(element['user_ratings_total'])
    types.append(element['types'])
	
place_df = pd.DataFrame({'Name': name, 'Latitude': lat, 'Place_ID': place_id, 
                          'Longitude': lng, 'Rating': rating, 'Total Reviews': user_ratings_total, 
                          'Types': types})
place_df.head()
# Out:
#                                                 Name   Latitude  \
# 0                           Aloft Cleveland Downtown  41.500571
# 1                        Renaissance Cleveland Hotel  41.498611
# 2        Metropolitan at the 9, Autograph Collection  41.499788
# 3  The Tudor Arms Hotel Cleveland - a DoubleTree ...  41.500816
# 4             Holiday Inn Express Cleveland Downtown  41.500186
#
#                       Place_ID  Longitude  Rating  Total Reviews  \
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w -81.704115     4.2           1061
# 1  ChIJQdJiRX7wMIgRMHYixWs56JQ -81.694472     4.1           1093
# 2  ChIJE6DsqoD6MIgRheks77AlZ9w -81.685809     4.5            982
# 3  ChIJM5WTlIT7MIgRZXbXABw3OQw -81.612958     4.3            870
# 4  ChIJ8b9IeID6MIgRg7cfACiPh8I -81.688767     4.3            912
#
#                                          Types
# 0  [lodging, point_of_interest, establishment]
# 1  [lodging, point_of_interest, establishment]
# 2  [lodging, point_of_interest, establishment]
# 3  [lodging, point_of_interest, establishment]
# 4  [lodging, point_of_interest, establishment]

# %%
# Build base url for text search 
nearby_type = "lodging"
target_coordinates = '41.5048, -81.6857'
radius = 1609
target_search = 'hotel'

nearby_url3 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=CtQDxQEAAHP-eofUyUhkQKLM3bteq6fF8YmhTngdVcRPIE-3jWrzytdLN7eRFp8RNFEv2f1m3s--89D1AKJ-jj0-v1S9UYn5YCXX4-wX48wWrVWeKBsFuJVmNWSxZVQrPoi65Qo0PPOR4HQIKcOIGK13KoRwVcETXUb4PcHJzEdH1beZXNkB6sGLVL5EEAgbXGh7Ac8dfDAedlROxwapMvmJuQOFLjYjwlany5YveJHxWjYYw7ANyXM2qJphcK-3G8A1W0jN_HB_nsplCO4tqdQIrbZ4FpUxnU-EKvi6XKbcdW8nxGXfsZPP3vyNdHAZrVTdiMcz5NczmYjxftBum30pfdwHO88e_a_uf5_qY4jrkJTWbzDo05itKmMjnklvAwwj6t2qKOV_c-d5Lg_y1BnAXDLjy-56NBBw41K2NWbpVEtm8YhQnNKpZBks63cdHwYg_eBukZjaSacEtep4zPEnsyRl7cteh0xwuzqSqtHUk6fCV36hN_yKCL32RrMu6fWz8G1nMhabbYLUKt_Ci0PtG_KSkpNXkPwP0ytm7EsLY0512x2rapFhAk0di2yNh1ObVj-i9MorP3jLt4g64mP6ix1Li9S6hp-y2nnVLuBB9oCcjv22EhC-TC633ik6rgBUJEhUGwUrGhTinhof5KsY2WJmN_1OUOGK9Nz3eA"

params = {"type" : nearby_type,
          'keyword' : target_search,
         "location" : target_coordinates,
          'radius': radius,
         "key" : gkey}

response = requests.get(nearby_url3, params=params)
cleveland_nearby3 = response.json()

print(json.dumps(cleveland_nearby3, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5059501,
#                     "lng": -81.6172965
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50729702989273,
#                         "lng": -81.61581612010727
#                     },
#                     "southwest": {
#                         "lat": 41.50459737010728,
#                         "lng": -81.61851577989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c8d0c7cc9d7914d642c6f0527b5cf053c658ea87",
#             "name": "Residence Inn",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107450849509407959993/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAflRoQHfuHs1jUVbEfb5pwKh6-3MNYhEMfzVvtNbXbLZ3QoSriIora6p1FUH61Ay9qPqiF2xPf1CN9zH-yLmuuoYzW26tZh7PaR_l9HysvriPcWRhCmmhD8dqjISnDl-QEhDgaI6PtZ8tC61uyh1Pp_ElGhRxDKh_jXYctgyqaBgJXgun8oGYCw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJyU-ZYZD7MIgR0UzjaUGy5tM",
#             "plus_code": {
#                 "compound_code": "G94M+93 Cleveland, Ohio, USA",
#                 "global_code": "86HWG94M+93"
#             },
#             "rating": 3.7,
#             "reference": "ChIJyU-ZYZD7MIgR0UzjaUGy5tM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "1914 E 101st St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.48529,
#                     "lng": -81.75155
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.48685122989272,
#                         "lng": -81.75012602010729
#                     },
#                     "southwest": {
#                         "lat": 41.48415157010727,
#                         "lng": -81.75282567989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "75cafe9b53c3e97e81139d73a413c51923989ab7",
#             "name": "JARVIS Edgewater Park & Beach 5BD Villa-Hotel",
#             "place_id": "ChIJ41F7Ur_xMIgR7X6vlVP17ZM",
#             "plus_code": {
#                 "compound_code": "F6PX+49 Cleveland, Ohio, USA",
#                 "global_code": "86HWF6PX+49"
#             },
#             "rating": 3,
#             "reference": "ChIJ41F7Ur_xMIgR7X6vlVP17ZM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "9845 Lake Ave, Cleveland"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Building lists 
for element in cleveland_nearby3['results']:
    lat.append(element['geometry']['location']['lat'])
    lng.append(element['geometry']['location']['lng'])
    name.append(element['name'])
    place_id.append(element['place_id'])
    rating.append(element['rating'])
    user_ratings_total.append(element['user_ratings_total'])
    types.append(element['types'])

place_df = pd.DataFrame({'Name': name, 'Place_ID': place_id, 'Latitude': lat, 'Longitude': lng, 'Rating': rating,
                          'Total Reviews': user_ratings_total, 'Types': types})
place_df.head()
# Out:
#                                                 Name  \
# 0                           Aloft Cleveland Downtown
# 1                        Renaissance Cleveland Hotel
# 2        Metropolitan at the 9, Autograph Collection
# 3  The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 4             Holiday Inn Express Cleveland Downtown
#
#                       Place_ID   Latitude  Longitude  Rating  Total Reviews  \
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1061
# 1  ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1093
# 2  ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            982
# 3  ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            870
# 4  ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            912
#
#                                          Types
# 0  [lodging, point_of_interest, establishment]
# 1  [lodging, point_of_interest, establishment]
# 2  [lodging, point_of_interest, establishment]
# 3  [lodging, point_of_interest, establishment]
# 4  [lodging, point_of_interest, establishment]

# %%
place_df2 = place_df[['Name','Place_ID','Latitude','Longitude','Rating','Total Reviews']]
place_df2.head()
# Out:
#                                                 Name  \
# 0                           Aloft Cleveland Downtown
# 1                        Renaissance Cleveland Hotel
# 2        Metropolitan at the 9, Autograph Collection
# 3  The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 4             Holiday Inn Express Cleveland Downtown
#
#                       Place_ID   Latitude  Longitude  Rating  Total Reviews
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1061
# 1  ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1093
# 2  ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            982
# 3  ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            870
# 4  ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            912

# %%
# Dropping non-hotels (for example, redspot is a parking garage)
place_df2["Name"] = place_df2["Name"].replace(
    {'The Bumpus House' : 'NaN', 'FLEX Spas Cleveland' : 'NaN',
    'The Alcazar' : 'NaN', 'Park Today' : 'NaN', 'catawba yacht club': 'NaN',
    'redspot' : "NaN", "1800 Euclid Hospitality Group" : "NaN", 
     "A Christmas Story House Loft Rental" : "NaN", 
    'hotels' : 'NaN', 'Urban Design Suite' : 'NaN', 
    "Casino Hotel" : "NaN", "USA" : "NaN"})
place_df2

place_df3 = place_df2.drop_duplicates()
place_df4 = place_df3[place_df3["Name"]!="NaN"]
place_df4.head()
# Out:
# C:\Users\gaston.alvarado\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                 Name  \
# 0                           Aloft Cleveland Downtown
# 1                        Renaissance Cleveland Hotel
# 2        Metropolitan at the 9, Autograph Collection
# 3  The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 4             Holiday Inn Express Cleveland Downtown
#
#                       Place_ID   Latitude  Longitude  Rating  Total Reviews
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1061
# 1  ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1093
# 2  ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            982
# 3  ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            870
# 4  ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            912

# %%
# Reset the index 
place_df5 = place_df4.reset_index()
place_df5

del place_df5['index']
place_search=place_df5
place_search.head()
# Out:
#                                                 Name  \
# 0                           Aloft Cleveland Downtown
# 1                        Renaissance Cleveland Hotel
# 2        Metropolitan at the 9, Autograph Collection
# 3  The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 4             Holiday Inn Express Cleveland Downtown
#
#                       Place_ID   Latitude  Longitude  Rating  Total Reviews
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1061
# 1  ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1093
# 2  ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            982
# 3  ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            870
# 4  ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            912

# %%
place_search_id=place_search["Place_ID"]
place_search_id
# Out:
# 0     ChIJ-V-1mmLwMIgRCNkQ5iY0w6w
# 1     ChIJQdJiRX7wMIgRMHYixWs56JQ
# 2     ChIJE6DsqoD6MIgRheks77AlZ9w
# 3     ChIJM5WTlIT7MIgRZXbXABw3OQw
# 4     ChIJ8b9IeID6MIgRg7cfACiPh8I
# 5     ChIJkyQK63j6MIgR3WshTHAP94Q
# 6     ChIJ9WAy2YDwMIgRqgktebGbYoM
# 7     ChIJ0bg0mIn7MIgRdLO0rIQ4ndc
# 8     ChIJtxcBOYb6MIgRW5MU3e2Lqew
# 9     ChIJlzqOKX7wMIgRcG1mp3KKt8s
# 10    ChIJz9VrMIDwMIgRU4dHrxBVI1k
# 11    ChIJjQ5B2YHwMIgRjNnpAsJKuBg
# 12    ChIJx3A1jKL7MIgRQwfzeK-X6Mc
# 13    ChIJY8UhA2L6MIgRjU4eiYtqbnM
# 14    ChIJewgGqX_6MIgRVI5s1kAUzyk
# 15    ChIJm_rT55v7MIgRkVJ4n5CNiOE
# 16    ChIJs9bne5j7MIgRK7gn3Ut37mE
# 17    ChIJ6fFs8X7wMIgR2muORRtGlpc
# 18    ChIJuemwd4zxMIgRR3D4Z1ZgDsg
# 19    ChIJowjHoID6MIgRYkqUBQC5bmk
# 20    ChIJU79i-X_6MIgRgAo4Y1a36zw
# 21    ChIJc3VeZFn6MIgRDfZmd6I8NQo
# 22    ChIJv1Qamov7MIgRAUiBRQkU2-A
# 23    ChIJp252m336MIgRX9QDJIGuKFU
# 24    ChIJn72y7Xj6MIgRRjyFgT8IMZk
# 25    ChIJ1TzoxJv7MIgRWiijLUrBJrE
# 26    ChIJyU-ZYZD7MIgR0UzjaUGy5tM
# 27    ChIJ6xhOyTP7MIgRG5i0LXBcqn8
# 28    ChIJ41F7Ur_xMIgR7X6vlVP17ZM
# Name: Place_ID, dtype: object

# %%
# Build base url for place details search 
base_url="https://maps.googleapis.com/maps/api/place/details/json?"

# Building lists
hotels=place_search_id
reviews = []
place_id=[]
name_det=[]
author_name=[]
relative_time_description=[]
text=[]
time=[]
place_id_rev=[]

#looping through the url 
for i in range(len(hotels)):
    try:
        params = {"place_id":hotels[i], "key" : gkey}
        response = requests.get(base_url, params=params)
        cleveland_details = response.json()
            
        for review in cleveland_details['result']['reviews']:
            place_id_rev.append(hotels[i])
            text.append(review['text'])
            time.append(review['time'])
            relative_time_description.append(review['relative_time_description'])
            author_name.append(review['author_name'])
            
        place_id.append(cleveland_details["result"]["place_id"])
        name_det.append(cleveland_details['result']['name'])

    except Exception:
        print("skipping")
    
#building the dataframe for place_id       
search_det = pd.DataFrame({'Place_ID': place_id,'Name': name_det})

#building the dataframe for reviews       
search_det_rev = pd.DataFrame({'Place_ID': place_id_rev, 'Author': author_name, 
                               'Text': text,'Relative Time':relative_time_description,'Time':time})
#Merging the two dataframes
combined_data=pd.merge(search_det_rev,search_det,how='left',on='Place_ID')
combined_data.head()
# Out:
# skipping
# skipping
# skipping
#                       Place_ID            Author  \
# 0  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w        Sean Tyler
# 1  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w        Mary Arida
# 2  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w        Ben Becker
# 3  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w          Dude Guy
# 4  ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  Sorhaindo Ofelia
#
#                                                 Text     Relative Time  \
# 0  Great hotel! Staff are fantastic! Food selecti...  in the last week
# 1  Great meeting with Aloft today! Planning a wed...      2 months ago
# 2  Great location if you're looking for a little ...       a month ago
# 3  While I myself did not have a reservation nor ...      2 months ago
# 4  If anybody is trying to find good deals for ho...      3 months ago
#
#          Time                      Name
# 0  1553518706  Aloft Cleveland Downtown
# 1  1547939229  Aloft Cleveland Downtown
# 2  1550343212  Aloft Cleveland Downtown
# 3  1548427590  Aloft Cleveland Downtown
# 4  1544833462  Aloft Cleveland Downtown

# %%
#Fetch wordcount for each abstract
combined_data['word_count'] = combined_data['Text'].apply(lambda x: len(str(x).split(" ")))
combined_data[['Text','word_count']].head(5)
# Out:
#                                                 Text  word_count
# 0  Great hotel! Staff are fantastic! Food selecti...          78
# 1  Great meeting with Aloft today! Planning a wed...          30
# 2  Great location if you're looking for a little ...          23
# 3  While I myself did not have a reservation nor ...         255
# 4  If anybody is trying to find good deals for ho...          57

# %%
##Descriptive statistics of word counts
combined_data.word_count.describe()
# Out:
# count    126.000000
# mean      69.007937
# std       59.058953
# min        1.000000
# 25%       36.000000
# 50%       55.000000
# 75%       80.750000
# max      372.000000
# Name: word_count, dtype: float64

# %%
#The average word count is about 71 words per abstract. 
#The word count ranges from a minimum of 1 to a maximum of 372.

# %%
#Identify common words
freq = pd.Series(' '.join(combined_data['Text']).split()).value_counts()[:20]
freq
# Out:
# the      371
# and      358
# a        227
# to       225
# was      216
# I        159
# is       114
# The      114
# for      109
# in       106
# of        90
# very      86
# hotel     65
# were      61
# room      61
# had       60
# with      58
# at        57
# on        54
# they      50
# dtype: int64

# %%
#Identify uncommon words
freq1 =  pd.Series(' '.join(combined_data ['Text']).split()).value_counts()[-20:]
freq1
# Out:
# microwaved     1
# worked.        1
# spotlessly     1
# wouldn't       1
# impeccably     1
# smells         1
# Left           1
# hotel's        1
# hallways,      1
# fan.           1
# management.    1
# saw            1
# ignore         1
# screaming      1
# Top            1
# drip           1
# painful        1
# attending      1
# coffee,        1
# cut            1
# dtype: int64

# %%
# Libraries for text preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
#nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer

# %%
##Creating a list of stop words and adding custom stopwords
#stop_words = set(stopwords.words("english"))
##Creating a list of custom stopwords
#new_words = ["using", "show", "result", "large", "also", "iv", "one", "two", "new", "previously", "shown"]
#stop_words = stop_words.union(new_words)

# %%
# Libraries for text preprocessing
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer

stop_words = set(stopwords.words("english"))

##Creating a list of custom stopwords
new_words = ["hilton", "com", "one", "hotelbuily","nd","hotel",
             "sunrise","morning","corner","work","cleveland","downtown","night","year","traveling","spend","stayed"]
stop_words = stop_words.union(new_words)

corpus = []

for i in range(0, 34):
    #Remove punctuations
    text_corp = re.sub('[^a-zA-Z]', ' ', combined_data['Text'][i])
    
    #Convert to lowercase
    text_corp = text_corp.lower()
    
    #remove tags
    text_corp=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text_corp)
    
    # remove special characters and digits
    text_corp=re.sub("(\\d|\\W)+"," ",text_corp)
    
    ##Convert to list from string
    text_corp = text_corp.split()
    
    ##Stemming
    ps=PorterStemmer()
   
    #Lemmatisation
    lem = WordNetLemmatizer()
    text_corp = [lem.lemmatize(word) for word in text_corp if not word in  
            stop_words] 
    text_corp = " ".join(text_corp)
    corpus.append(text_corp)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gaston.alvarado\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gaston.alvarado\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
corpus[33]
# Out:
# 'staff really great left behind book held called find book staff able mail home really nice people'

# %%
#Word cloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x00000257FE1A6860>

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re
cv=CountVectorizer(max_df=0.8,stop_words=stop_words, max_features=10000, ngram_range=(1,3))
X=cv.fit_transform(corpus)

# %%
list(cv.vocabulary_.keys())[:10]
# Out:
# ['great',
#  'staff',
#  'fantastic',
#  'food',
#  'selection',
#  'ignore',
#  'important',
#  'note',
#  'impact',
#  'score']

# %%
#Most frequently occuring words
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]

#Convert most freq words to dataframe for plotting bar plot
top_words = get_top_n_words(corpus, n=10)
top_df = pd.DataFrame(top_words)
top_df.columns=["Word", "Freq"]

#Barplot of most freq words
import seaborn as sns

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 8))

# Load the example car crash dataset
words = top_df.sort_values("Freq", ascending=False)

#Barplot of most freq Bi-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
h=sns.barplot(x="Word", y="Freq", data=top_df)
h.set_xticklabels(h.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'room'),
#  Text(0, 0, 'staff'),
#  Text(0, 0, 'nice'),
#  Text(0, 0, 'great'),
#  Text(0, 0, 'would'),
#  Text(0, 0, 'stay'),
#  Text(0, 0, 'clean'),
#  Text(0, 0, 'friendly'),
#  Text(0, 0, 'beautiful'),
#  Text(0, 0, 'check')]

# %%
#Most frequently occuring words
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]

#Convert most freq words to dataframe for plotting bar plot
top_words = get_top_n_words(corpus, n=20)
top_df = pd.DataFrame(top_words)
top_df.columns=["Word", "Freq"]

#Barplot of most freq words
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
g = sns.barplot(x="Word", y="Freq", data=top_df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'room'),
#  Text(0, 0, 'staff'),
#  Text(0, 0, 'nice'),
#  Text(0, 0, 'great'),
#  Text(0, 0, 'would'),
#  Text(0, 0, 'stay'),
#  Text(0, 0, 'clean'),
#  Text(0, 0, 'friendly'),
#  Text(0, 0, 'beautiful'),
#  Text(0, 0, 'check'),
#  Text(0, 0, 'experience'),
#  Text(0, 0, 'go'),
#  Text(0, 0, 'location'),
#  Text(0, 0, 'everything'),
#  Text(0, 0, 'day'),
#  Text(0, 0, 'next'),
#  Text(0, 0, 'cool'),
#  Text(0, 0, 'good'),
#  Text(0, 0, 'ready'),
#  Text(0, 0, 'time')]

# %%
#Most frequently occuring Bi-grams
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top2_words = get_top_n2_words(corpus, n=20)
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
print(top2_df)

#Barplot of most freq Bi-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
h=sns.barplot(x="Bi-gram", y="Freq", data=top2_df)
h.set_xticklabels(h.get_xticklabels(), rotation=45)

# %%
#Most frequently occuring Tri-grams
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top3_words = get_top_n3_words(corpus, n=20)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]
print(top3_df)

#Barplot of most freq Tri-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
j=sns.barplot(x="Tri-gram", y="Freq", data=top3_df)
j.set_xticklabels(j.get_xticklabels(), rotation=45)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
 
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(X)
# get feature names
feature_names=cv.get_feature_names()
 
# fetch document for which keywords needs to be extracted
doc=corpus[33]
 
#generate tf-idf for the given document
tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))


#Function for sorting tf_idf in descending order
from scipy.sparse import coo_matrix
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
 
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
 
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results
#sort the tf-idf vectors by descending order of scores
sorted_items=sort_coo(tf_idf_vector.tocoo())
#extract only the top n; n here is 10
keywords=extract_topn_from_vector(feature_names,sorted_items,20)
 
# now print the results
print("Text:")
print(doc)
print("\nKeywords:")
for k in keywords:
    print(k,keywords[k])
