# %%
# Import dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json 
import requests
import time
from citipy import citipy
import urllib

# Import api key 
from api_keys import gkey

# %%
text_type = "lodging"
location = "hotels in Cuyahoga County"

text_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

params = {"type" : text_type,
         "query" : location,
         "key" : gkey}

response = requests.get(text_url, params=params)
cuyahoga_text = response.json()

print(json.dumps(cuyahoga_text, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCEQEAAKok-2GtRow331Qr5tJIUnTyobFVu_AZpOthMd4X3Rctjn-UAlBIYP5LHtLvByeAbSqjAmgWsPq_crEEK9z-01nCavaf809jJiK0aUu5Sim3chUfwcE1Ckn_DYbo1A0QFFXUSRFf66JBHUf8F8Xwcl0M1AAzx98OTARsjcEOe8Pt4qzBNTuw2KuMNbezIjwJwcrhhrkORnT5wF_UwVvIODDjLc9Am_rLbU4BlAYjMd8cDayUSymoB3QJI2CDCl1tLQns0VNIPb9qKsYJb84VFPs2QIUPTo_xFz2eUi_iIVstrDMXTrcDskU8Ro1UemO_nXNaUHoWwQZgvwzN1l93d4RXokzM40_Fyma5dwDQOBZJzsIgdXM_9GbbmrcPK9McyBIQbqlXTj80D-NOV_kc0Y4RYBoUx5HYfo5mN0zUPEMnwcYtTFBF4Vk",
#     "results": [
#         {
#             "formatted_address": "629 Euclid Ave, Cleveland, OH 44114, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.5001855,
#                     "lng": -81.688767
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50146237989272,
#                         "lng": -81.68742177010729
#                     },
#                     "southwest": {
#                         "lat": 41.49876272010728,
#                         "lng": -81.69012142989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "540b9cccc650b7e2f2219b63c22ec88b3291f43e",
#             "name": "Holiday Inn Express Cleveland Downtown",
#             "photos": [
#                 {
#                     "height": 1371,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100565948717289391741/photos\">Holiday Inn Express</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgzgppkCgoqUQZahUTWHxFi1iLbrIfGFk0NdXHNQIx65K2BO0rZ03MpPqv2qNWA5TsCd1V4kGuUdCdoGcm8-GxeyIaR22_N3vW7uUYkqkso-9WSka1AAmkK3nPtooouZ_EhBIbMRL2yi4ErLjuLyZi_LgGhRLR0jqRgLmOEmquMop3nWDBLu7fQ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ8b9IeID6MIgRg7cfACiPh8I",
#             "plus_code": {
#                 "compound_code": "G826+3F Cleveland, Ohio, USA",
#                 "global_code": "86HWG826+3F"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ8b9IeID6MIgRg7cfACiPh8I",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 903
#         },
#         {
#             "formatted_address": "1460 E 9th St, Cleveland, OH 44114, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.502438,
#                     "lng": -81.689041
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50374242989272,
#                         "lng": -81.68757202010728
#                     },
#                     "southwest": {
#                         "lat": 41.50104277010728,
#                         "lng": -81.69027167989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c5346f7cd1d5b797021f4d91e61c6e54aae1b52e",
#             "name": "Hampton Inn Cleveland-Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111748181403513024778/photos\">Hampton Inn Cleveland-Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgy7rhdny2W9biOFAxXOZHCoBUXUpVqfu_wFShT-7x1av0NpUxXgDUmKGZhbKqX_ROiNyPCIrpaJNeFFcbpjOEkZrhK-0ksSIAu6K-goDDvYYaxpQnyCGGrxT8KZB-SYOEhDbmGoDZ-DNdEn7zozl1SoSGhSr1ysQh_TUYLcGXVN45as8YdJpdw",
#                     "width": 1331
#                 }
#             ],
#             "place_id": "ChIJewgGqX_6MIgRVI5s1kAUzyk",
#             "plus_code": {
#                 "compound_code": "G826+X9 Cleveland, Ohio, USA",
#                 "global_code": "86HWG826+X9"
#             },
#             "rating": 4.2,
#             "reference": "ChIJewgGqX_6MIgRVI5s1kAUzyk",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 883
#         },
#         {
#             "formatted_address": "15471 Royalton Rd, Strongsville, OH 44136, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.3116804,
#                     "lng": -81.80746049999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.31315207989272,
#                         "lng": -81.80586907010728
#                     },
#                     "southwest": {
#                         "lat": 41.31045242010728,
#                         "lng": -81.80856872989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8fa77657b9fce1f5d1b393dbef0871d35c972334",
#             "name": "Holiday Inn Cleveland-Strongsville (Arpt)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1251,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103801237062170500893/photos\">Holiday Inn Cleveland-Strongsville (Arpt)</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAge_sqSe8qlx2sl1M2rYxJFSqmyawRKPP8uBZIs2MKDMexs9BMXYI8GabtS3ApYQUId4NbXxL_UBD6PWoERkb4Sx4FbYJlrsztZbbHf0-_1qZF9tQhDOxxXIpKdG7EPegEhA_flFxhLjfVre0EB-zO0RJGhTj1N1J_4I9azV8ZU_GebRYcsO8pg",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJw7NyZnbqMIgREvjeepQ5ipg",
#             "plus_code": {
#                 "compound_code": "856V+M2 Strongsville, Columbia Township, OH, USA",
#                 "global_code": "86HW856V+M2"
#             },
#             "rating": 4,
#             "reference": "ChIJw7NyZnbqMIgREvjeepQ5ipg",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 840
#         },
#         {
#             "formatted_address": "4181 W 150th St, Cleveland, OH 44135, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.4407282,
#                     "lng": -81.79997449999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.44220232989272,
#                         "lng": -81.79868322010726
#                     },
#                     "southwest": {
#                         "lat": 41.43950267010727,
#                         "lng": -81.80138287989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f48e80f79f0e15ca91163bbeb445a033af8dfc77",
#             "name": "Four Points by Sheraton Cleveland Airport",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 450,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106938851058448467334/photos\">Four Points by Sheraton Cleveland Airport</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIOVCxKtL-MtxkBYrh1j5kiWeuVcYuUKPIqyOD9D-iNmST_IhOVpYHCZxqJpP8bFbMhD8gZzCfr_AJMd5sEylEKueFTeBzLHa_lWlSGHdvCjKX1U6LqqhzS2AJRXRZjKUEhAvbGYaXfu3FcMJeN99CgbCGhRvTPapj6rvCEgiPeaeHUqm-vVNSQ",
#                     "width": 450
#                 }
#             ],
#             "place_id": "ChIJ30Eig8ftMIgRG8CeJcCSpEM",
#             "plus_code": {
#                 "compound_code": "C6R2+72 Cleveland, Ohio, USA",
#                 "global_code": "86HWC6R2+72"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ30Eig8ftMIgRG8CeJcCSpEM",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 547
#         },
#         {
#             "formatted_address": "23300 Oakwood Commons Dr, Oakwood, OH 44146, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.3679735,
#                     "lng": -81.5095802
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.36931197989271,
#                         "lng": -81.50823117010728
#                     },
#                     "southwest": {
#                         "lat": 41.36661232010727,
#                         "lng": -81.51093082989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d773a621620bc00cc952cdc385d46c18f1232d32",
#             "name": "Hampton Inn & Suites Oakwood Village-Cleveland",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110918334905302914609/photos\">Tsheed1 .</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaMTxzYjWkcGub_5udr7JM8Z9ptf7JNqCPUz7y3jtzb9zsKe9Op5vAV8iChPuIPsXTdX3HR6ZYwuLPypDf3XccF6t1riaCKQFMWqiS2s9FtrwJE2_BjpwGdlSQghAltcVEhC210hFjlG4zA8SZy3MVd5aGhR-UBPAwjX2Cs5g4zwbTxsjen_Tmg",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJAxEL-v0dMYgRb44-JhHqJGs",
#             "plus_code": {
#                 "compound_code": "9F9R+55 Oakwood, Ohio, USA",
#                 "global_code": "86HW9F9R+55"
#             },
#             "rating": 4.4,
#             "reference": "ChIJAxEL-v0dMYgRb44-JhHqJGs",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 150
#         },
#         {
#             "formatted_address": "6191 Quarry Ln, Independence, OH 44131, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.393017,
#                     "lng": -81.64881500000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.39472902989272,
#                         "lng": -81.64785412010728
#                     },
#                     "southwest": {
#                         "lat": 41.39202937010728,
#                         "lng": -81.65055377989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9d1300a0afb9b18a1be106e21fd2a38afbc53ef1",
#             "name": "Comfort Inn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 499,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105615531086039931779/photos\">Comfort Inn</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAeStEP3DZTtPDUXn7_-hdYpg7blUb0djEoYhH9jTmOjZk5iArLGDqpBiTNlTsjxK33Mc8y7UgMnK7yve8Up_TJW91rF2OKgUwyQfAC2193ooVGdIehXp1K_eNekSfGfnFEhBMrvT64z1ZkH7cV_xHZvnwGhSDREEGGKo9ybX6plShnI2EvMXouw",
#                     "width": 499
#                 }
#             ],
#             "place_id": "ChIJO-UsYcvlMIgRtzJnC5IQIaU",
#             "plus_code": {
#                 "compound_code": "99V2+6F Independence, Ohio, USA",
#                 "global_code": "86HW99V2+6F"
#             },
#             "rating": 4,
#             "reference": "ChIJO-UsYcvlMIgRtzJnC5IQIaU",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "point_of_interest",
#                 "food",
#                 "establishment"
#             ],
#             "user_ratings_total": 311
#         },
#         {
#             "formatted_address": "7233 Engle Rd, Middleburg Heights, OH 44130, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.3701437,
#                     "lng": -81.824074
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.37142057989272,
#                         "lng": -81.82272302010726
#                     },
#                     "southwest": {
#                         "lat": 41.36872092010727,
#                         "lng": -81.82542267989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "61efbde8842adf94e9632ccc01f91cb095b9c8f9",
#             "name": "Days Inn by Wyndham Middleburg Heights",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 257,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112948388263490307244/photos\">Days Inn Cleveland Airport South</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjUMNWL7bzDmwRJX8JzQijMZ29_8TdDnHw2g_YTrUf6eQEVkOq2CNL2PqP-a_O3F5AOxiWSnT4fKUd8tkiRrFQbwGxs0u1hLT8JWja_11EeSlW7ZM0QUtOKoI-opgBjdxEhDhUiWWwpo3JDRjE2KxImf2GhRETMvk25F4iB5te6rpgtpHww5Icw",
#                     "width": 338
#                 }
#             ],
#             "place_id": "ChIJKTfVyQrrMIgRJXdS5pYIa0c",
#             "plus_code": {
#                 "compound_code": "95CG+39 Middleburg Heights, Ohio, USA",
#                 "global_code": "86HW95CG+39"
#             },
#             "rating": 3.1,
#             "reference": "ChIJKTfVyQrrMIgRJXdS5pYIa0c",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 417
#         },
#         {
#             "formatted_address": "5800 Rockside Woods Blvd N, Independence, OH 44131, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.4021392,
#                     "lng": -81.647121
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.40339647989272,
#                         "lng": -81.64533582010728
#                     },
#                     "southwest": {
#                         "lat": 41.40069682010728,
#                         "lng": -81.64803547989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8890492f90e8c87a404c5fff121f8bb97e788cb5",
#             "name": "Embassy Suites by Hilton Cleveland Rockside",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2740,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100029061282930268407/photos\">Embassy Suites Cleveland - Rockside</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA78QwNqMkzVvQsvp254Q2KMCT50WIXe0ZvfJD7UK-9SScgTWG4vYWdEZmXtSqNEBjnAPSr2VkN5MN4pu8abopwdzZLCerR82mMORFE52f6bOAiKQ_-0NQOAotFsA-f2cCEhCJqfDyGgA_KVIYLyrPxLJAGhRG-tohhRmebTG-dFD2tVtrgIW6UQ",
#                     "width": 4872
#                 }
#             ],
#             "place_id": "ChIJEfl9WkvkMIgRmsZ5kX7sXhE",
#             "plus_code": {
#                 "compound_code": "C923+V5 Independence, Ohio, USA",
#                 "global_code": "86HWC923+V5"
#             },
#             "rating": 4.2,
#             "reference": "ChIJEfl9WkvkMIgRmsZ5kX7sXhE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1355
#         },
#         {
#             "formatted_address": "1800 Euclid Ave, Cleveland, OH 44115, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.500889,
#                     "lng": -81.678405
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50228122989271,
#                         "lng": -81.67703937010727
#                     },
#                     "southwest": {
#                         "lat": 41.49958157010727,
#                         "lng": -81.67973902989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "b2f9ce02f7a0a36238e6f88890c847ce02ccf6a1",
#             "name": "Comfort Inn Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104053446268520505265/photos\">CS3Design Inc</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAK-UkZNcuscfAA3yxUCYAStH6_SIKxLWSf7y4Q2GAmGXg8C0vVpcQAUlYuzm1SlcsXmlNTbI-7kTtPw026YWirHQPL6gOULWUP6NnLHse4MyhoIKKzYe1JTh8LLSfl_GUEhAA1vaE_QrWEVpBj3rq0LlMGhTp0d658P5c4HIfJEp1ZD-MqBqoWw",
#                     "width": 4272
#                 }
#             ],
#             "place_id": "ChIJjZYp7GL6MIgRT7wZtpIDVMs",
#             "plus_code": {
#                 "compound_code": "G82C+9J Cleveland, Ohio, USA",
#                 "global_code": "86HWG82C+9J"
#             },
#             "rating": 4,
#             "reference": "ChIJjZYp7GL6MIgRT7wZtpIDVMs",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 710
#         },
#         {
#             "formatted_address": "6020 Jefferson Dr, Independence, OH 44131, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.4017991,
#                     "lng": -81.65296819999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.40317817989272,
#                         "lng": -81.65181712010727
#                     },
#                     "southwest": {
#                         "lat": 41.40047852010727,
#                         "lng": -81.65451677989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "09219515a05224df4e44861b3f801e85353441de",
#             "name": "Hampton Inn & Suites Cleveland/Independence",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107210960195823270498/photos\">Hampton Inn &amp; Suites Cleveland/Independence</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxK4Npc8j4VUKu15kaC0m3aZxYOUilP_vfNgwQe3LxSSvQAyu3SptqfiadJJpvKgIawPo4qmf1XXGEY_s3yeDnUS4q5EaThY7pynGbG3kr8ggTVNV_Oaig48YQ7i8SK2YEhA4_9PTWEBLxGNDjqXPduQqGhRrf3tWaF7hnWLhV3v2A9GxOKbZ1A",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJGz_MprblMIgRBI4pehiHayo",
#             "plus_code": {
#                 "compound_code": "C82W+PR Independence, Ohio, USA",
#                 "global_code": "86HWC82W+PR"
#             },
#             "rating": 4.2,
#             "reference": "ChIJGz_MprblMIgRBI4pehiHayo",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 286
#         },
#         {
#             "formatted_address": "3614 Euclid Ave, Cleveland, OH 44115, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.5026862,
#                     "lng": -81.6619004
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50422482989272,
#                         "lng": -81.66059657010727
#                     },
#                     "southwest": {
#                         "lat": 41.50152517010728,
#                         "lng": -81.66329622989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "85b94cf3e0ba782387ccfcb044f4497e86453417",
#             "name": "University Hotel and Suites",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118191734931864390259/photos\">daniel biondo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5XyWjdP1lPJOHY_f2oe4RIMV8aUhKNKw8Jav_GVQrp2QYDtNmwkrWeaLP0_4NEwNNQowtK5oyPkwiea5n9iT63KQ6SCYF-mPPirDs7xLK6UN_Vef_yVI2P7XevJRFYm5EhCbznNl6dRGiwGg9_2oBtBxGhR0sJL4S87SZdM4eSiRATdd-Oh8gQ",
#                     "width": 2268
#                 }
#             ],
#             "place_id": "ChIJc3VeZFn6MIgRDfZmd6I8NQo",
#             "plus_code": {
#                 "compound_code": "G83Q+36 Cleveland, Ohio, USA",
#                 "global_code": "86HWG83Q+36"
#             },
#             "rating": 2.8,
#             "reference": "ChIJc3VeZFn6MIgRDfZmd6I8NQo",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 589
#         },
#         {
#             "formatted_address": "1260 Euclid Ave, Cleveland, OH 44115, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.5004615,
#                     "lng": -81.6833738
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50190117989273,
#                         "lng": -81.68204442010727
#                     },
#                     "southwest": {
#                         "lat": 41.49920152010728,
#                         "lng": -81.68474407989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "287b03d00231da73bac1cad7a805e09a2d0e795d",
#             "name": "Crowne Plaza Cleveland at Playhouse Square",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110636021344697030653/photos\">Brian Johnson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAd0aKP8Rjo75rRlFjBr-Ig-N7Jf-Py3kKrWtBuQhtwjg59gzvcJX9QB2y3utRWPBvThbJ-Ms4oZCWlDmt54xEFKL5xlBMJi32B_0tTmtgaXgoUiC7wVXL371DJdkscsxDEhCU4QaR-TKOnzMHNJweTL-iGhQ0IxK5_weBLgzwpFlesPDQ_8EOIg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJp252m336MIgRX9QDJIGuKFU",
#             "plus_code": {
#                 "compound_code": "G828+5M Cleveland, Ohio, USA",
#                 "global_code": "86HWG828+5M"
#             },
#             "rating": 4.2,
#             "reference": "ChIJp252m336MIgRX9QDJIGuKFU",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 505
#         },
#         {
#             "formatted_address": "1901 Ford Dr, Cleveland, OH 44106, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.5109436,
#                     "lng": -81.607877
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.51214097989272,
#                         "lng": -81.60672232010728
#                     },
#                     "southwest": {
#                         "lat": 41.50944132010728,
#                         "lng": -81.60942197989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e17ae10b89220409598b309cf1a927c1c8950b13",
#             "name": "Glidden House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107940753662136485035/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAZ5LXp1Pp0jIQ_lhBxerN09F23cSzjgKuux74Cn_nTETu8FTkIVApr9QUH2DdDooqZ2F2eQ8xHPnN_c7jhriyk9RuzjOpfid6ZWJDa25K-52tbSkKgIk0urA2Zq5SNhDmEhCPibLgwk5usmnBRYtAWy7BGhTOKog_SyZqPvBB2Mrh7-0j-eTa2Q",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJv1Qamov7MIgRAUiBRQkU2-A",
#             "plus_code": {
#                 "compound_code": "G96R+9R Cleveland, Ohio, USA",
#                 "global_code": "86HWG96R+9R"
#             },
#             "rating": 4.7,
#             "reference": "ChIJv1Qamov7MIgRAUiBRQkU2-A",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 337
#         },
#         {
#             "formatted_address": "7345 Engle Rd, Middleburg Heights, OH 44130, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.36737249999999,
#                     "lng": -81.82405829999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.36883477989272,
#                         "lng": -81.82276747010728
#                     },
#                     "southwest": {
#                         "lat": 41.36613512010727,
#                         "lng": -81.82546712989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5b98a729f52ae87dffc0942faa125416a7c75419",
#             "name": "Courtyard by Marriott Cleveland Airport South",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113071347258242424312/photos\">Kevin Dollhopf</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAKMWfqKtR9dM-R3OllSvJ_RrIQ-UfMZiS81kYGumsJy9MuQOzZhvW0Auf7rjxCrQgtpJnIBBF5aonpXY0nfxCjFmyUC-eaUqRpwlNBm2Tx5f0zlHa2J9uK5VOct4iG6TZEhCiM65k2Xg5Y_WGrd833mB1GhQ9DfX9ORJCAZsaVKX780cF0E29tA",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ3804QwrrMIgRN5RKPMoeM48",
#             "plus_code": {
#                 "compound_code": "958G+W9 Middleburg Heights, Ohio, USA",
#                 "global_code": "86HW958G+W9"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ3804QwrrMIgRN5RKPMoeM48",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 398
#         },
#         {
#             "formatted_address": "12019 Lake Ave, Lakewood, OH 44107, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.4894755,
#                     "lng": -81.7731469
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49101532989272,
#                         "lng": -81.77171747010728
#                     },
#                     "southwest": {
#                         "lat": 41.48831567010728,
#                         "lng": -81.77441712989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6891b62a9d1047bd7ce19b8a802b8991ea4b31a5",
#             "name": "Days Inn by Wyndham Cleveland Lakewood",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114602264570729086954/photos\">David Chudd</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAC2r0KUKL_TW3vjt-Mfu5Yq0ZTPfm4J9Bt_584Oj2pTd2SIOulL5_2eGFeiGdUYYu8m0yp6nm7EuDPX8HuuETfHHloTuRKawdZI_8rehPZvQSSk_hRiVHImdo5obeCSL0EhAycC85_e5grP4A_viP8NqkGhSO4lDwJpSkI1IA7G9odzqFsWIzGA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJuemwd4zxMIgRR3D4Z1ZgDsg",
#             "plus_code": {
#                 "compound_code": "F6QG+QP Lakewood, Ohio, USA",
#                 "global_code": "86HWF6QG+QP"
#             },
#             "rating": 2.7,
#             "reference": "ChIJuemwd4zxMIgRR3D4Z1ZgDsg",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 411
#         },
#         {
#             "formatted_address": "16330 Snow Rd, Brook Park, OH 44142, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.404109,
#                     "lng": -81.81230359999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.40531837989273,
#                         "lng": -81.81090247010728
#                     },
#                     "southwest": {
#                         "lat": 41.40261872010728,
#                         "lng": -81.81360212989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "37d54367071a1ac62688a134eb2bc8adc3cc9c54",
#             "name": "Holiday Inn Express Cleveland Airport - Brook Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101537379629636220931/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAABU8vfOsTS9OZca9phelveeppFxAAF-TtTVQjGYQBVbwo4Ga_qsz32lMTD4GOYKrZP-oEluE9ZyGhtTKNIxNEaaQ54wU28-5J8eP43cscLc4Klz1savfTvXZdr83gYL_pEhDk_bGGewBtlid9DVA7zgdXGhRl1HPdJ9Oe3VVX7KjDYo-srCw-sw",
#                     "width": 5993
#                 }
#             ],
#             "place_id": "ChIJK1c7w2XsMIgRgM5x7A44_ek",
#             "plus_code": {
#                 "compound_code": "C53Q+J3 Brook Park, Ohio, USA",
#                 "global_code": "86HWC53Q+J3"
#             },
#             "rating": 4.2,
#             "reference": "ChIJK1c7w2XsMIgRgM5x7A44_ek",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 343
#         },
#         {
#             "formatted_address": "1380 E 6th St, Cleveland, OH 44114, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.5021743,
#                     "lng": -81.69196860000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50371732989272,
#                         "lng": -81.69032442010729
#                     },
#                     "southwest": {
#                         "lat": 41.50101767010727,
#                         "lng": -81.69302407989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "cc1b9ed4c9c88db7f736792a02ba229ea1b367a7",
#             "name": "Drury Plaza Hotel Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4912,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102180379553984288471/photos\">Drury Plaza Hotel Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAQqIqxpQZbUoFgaO-g-pHfE_vlgo2xE1RzjxuNhv2mO3_sw4ROG18tNHD3p840ryTBTCmzV-IL69eCM7mX-BlZaRo7HCW0QF7n5dE4bXQ86_ZfI32F_wHW2ZV6uieJnkEhAstGZ9w3_1eZe85xaMfUOdGhTwhEpPHaA8ZetRZ0WdOw8N-Jh7Lw",
#                     "width": 7360
#                 }
#             ],
#             "place_id": "ChIJz9VrMIDwMIgRU4dHrxBVI1k",
#             "plus_code": {
#                 "compound_code": "G825+V6 Cleveland, Ohio, USA",
#                 "global_code": "86HWG825+V6"
#             },
#             "rating": 4.6,
#             "reference": "ChIJz9VrMIDwMIgRU4dHrxBVI1k",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1049
#         },
#         {
#             "formatted_address": "100 Lakeside Ave E, Cleveland, OH 44114, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030718,
#                     "lng": -81.6956723
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50416817989272,
#                         "lng": -81.69461932010728
#                     },
#                     "southwest": {
#                         "lat": 41.50146852010727,
#                         "lng": -81.69731897989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d48d9c2e557d51fde5c5bbe6879cd47a60303228",
#             "name": "Hilton Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4457,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110966001620855182613/photos\">Hilton Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAe_BTd4nHiaf-m3NbTu_vnn8OCUS7jUIEAcB86p4D1OQMK5IgffY-DsfAFEyuugKV4vRe9sRKuUUQOjr6rZpoEAjZ4jR9mjb-YhnDpAK3h8bk9g53-m5DnAocNE5QEopzEhD2XQRgXlS3fud-ltmM98W-GhSOmd9fNRHR5rs2CXeYlc6JHIvi0A",
#                     "width": 6447
#                 }
#             ],
#             "place_id": "ChIJ9WAy2YDwMIgRqgktebGbYoM",
#             "plus_code": {
#                 "compound_code": "G833+6P Cleveland, Ohio, USA",
#                 "global_code": "86HWG833+6P"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ9WAy2YDwMIgRqgktebGbYoM",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2141
#         },
#         {
#             "formatted_address": "1010 Eaton Blvd, Beachwood, OH 44122, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.4545719,
#                     "lng": -81.4990885
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.45574367989272,
#                         "lng": -81.49763477010727
#                     },
#                     "southwest": {
#                         "lat": 41.45304402010728,
#                         "lng": -81.50033442989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c257c7dcf73b8c32e5cee59864038e1edf2055b7",
#             "name": "Aloft Beachwood",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 450,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104415909156126400079/photos\">Aloft Beachwood</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXRPQpCbhaeI1Q9EAx69lUuar9bp52ZDIDklH3b_DbzbbRv7GuctB8ZNGUaxmlQdTqvO7rgZWMn3uwQuiQHFtYYjP8LFqsMTNfJBwhvi5DxPcNGVf763TuQAqSSHsMGMoEhCx2u_ij1otBB4996CSnVL5GhQWvJJTueUihcHi7aogWapCrtTd4A",
#                     "width": 450
#                 }
#             ],
#             "place_id": "ChIJ3c-QlLECMYgRx6zks9zAZ6w",
#             "plus_code": {
#                 "compound_code": "FG32+R9 Beachwood, Ohio, USA",
#                 "global_code": "86HWFG32+R9"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ3c-QlLECMYgRx6zks9zAZ6w",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 537
#         },
#         {
#             "formatted_address": "651 Huron Rd E, Cleveland, OH 44115, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.49813959999999,
#                     "lng": -81.6876913
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49941797989272,
#                         "lng": -81.68627552010727
#                     },
#                     "southwest": {
#                         "lat": 41.49671832010728,
#                         "lng": -81.68897517989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "72294e13a76fda86c653031d96c3cd83f93db718",
#             "name": "Radisson Hotel Cleveland-Gateway",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1087,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112162912760058964179/photos\">Ken Hill</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQXH9lHERmDx-fpcvVMYZG8LTefME4EziOIgWMe1mVSUmZyYUSrmjLQpNe_Y_5DIyu6Z2qJUYvyChYgIIQ6vF08mbKqN5lu7TadYPYJELSAdJKaeb2-Pl00GVXfoagDZGEhDL2M8wH4PTgAe4AE3ngEX8GhTIqVkxJdVzKu6unK-OhrW7m7iZsA",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJA-0v8ID6MIgRBACI0VNvqr8",
#             "plus_code": {
#                 "compound_code": "F8X6+7W Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X6+7W"
#             },
#             "rating": 3.9,
#             "reference": "ChIJA-0v8ID6MIgRBACI0VNvqr8",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 782
#         }
#     ],
#     "status": "OK"
# }

# %%
place_id_list=[]
lattitude = []
longitude = []
hotel_name = []
single_rating = []
user_ratings_total = []
#types = []

for i in range(len(cuyahoga_text["results"])):
    place_id = cuyahoga_text["results"][i]["place_id"]
    place_id_list.append(place_id)
    name = cuyahoga_text["results"][i]["name"]
    hotel_name.append(name)
    rating = cuyahoga_text["results"][i]["rating"]
    single_rating.append(rating)
    lat = cuyahoga_text["results"][i]["geometry"]["location"]["lat"]
    lattitude.append(lat)
    lng = cuyahoga_text["results"][i]["geometry"]["location"]["lng"]
    longitude.append(lng)
    user = cuyahoga_text["results"][i]["user_ratings_total"]
    user_ratings_total.append(user_ratings_total)

#Creating dataframe
place_search_data = pd.DataFrame({"Hotel ID": place_id_list,"Hotel Name": hotel_name,"Individual Rating":rating,
                                  "Lattitude":lattitude,"Longitude":longitude,"User Total Rating":user_ratings_total})
#Export and display dataframe
#weather_data.to_csv(r'output_data_file')
place_search_data
#single_rating

# %%
user = cuyahoga_text["results"][i]["user_ratings_total"]
user

# %%
place_id_list=[]

print(len(cuyahoga_text["results"]))

for i in range(len(cuyahoga_text["results"])):
    place_id = cuyahoga_text["results"][i]["place_id"]
    place_id_list.append(place_id)

clean_list=place_id_list
clean_list

# %%
# Build base url for place details search 
base_url="https://maps.googleapis.com/maps/api/place/details/json?"

#build the search for a Hotel, included the required fields
hotels="ChIJw7NyZnbqMIgREvjeepQ5ipg"
fields_included= "price_level,rating,review,place_id,user_ratings_total"

params = {"placeid": hotels,
         "fields": fields_included,
         "key" : gkey}

# Run request
response = requests.get(base_url, params=params)
hotel_details = response.json()

#print (hotel_details)
print(json.dumps(hotel_details, indent=4, sort_keys=True))
