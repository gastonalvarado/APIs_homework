# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#import openweathermapy.core as owm
from config import api_key

# Import API key
#from config import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units="metric"
query_url = f"{url}appid={api_key}&units={units}&q="

lat = []
temp=[]
lng=[]
humidity=[]
clouds=[]
winds=[]
city_list=[]
citylist=[]
#response_json = []

for city in cities:
    response=requests.get(query_url + city).json()
    try:      
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        lng.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        winds.append(response['wind']['speed'])
        citylist.append(city)    
    except:
        print(f"Processing record [citylist] of set | (city_list)")
        print (query_url + city)
        #print("Missing field/results...skipping")
        #print("------------------------------------------")
        #print(f"Data Retrieval Complete")
        #print("------------------------------------------")
# Out:
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=araguacu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=tsihombe
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=nizhneyansk
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=varadero
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=tumannyy
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=vaitupu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=barentsburg
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=sataua
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=amderma
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=leshan
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=belushya guba
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=umzimvubu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=krasnoselkup
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=lolua
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=taolanaro
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=yialos
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=tidore
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=skalistyy
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=gilazi
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=mormugao
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=illoqqortoormiut
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=taburi
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=linshu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=kegayli
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=ipora
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=rolim de moura
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=meyungs
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=novoyegoryevskoye
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=samusu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=marcona
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=bolungarvik
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=mrirt
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=sug-aksy
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=grand river south east
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=tabiauea
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=sentyabrskiy
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=mys shmidta
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=hurghada
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=calobre
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=domoni
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=sedelnikovo
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=olafsvik
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=raga
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=galiwinku
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=urumqi
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=hvammstangi
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=grand centre
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=inderborskiy
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=karamea
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=samalaeulu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=temaraia
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=kuche
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=attawapiskat
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=louisbourg
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=cazaje
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=korla
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=bengkulu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=haibowan
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=maloshuyka
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=burica
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=galgani
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=tucuma
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=nguiu
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=ondorhaan
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=zachagansk
# Processing record [citylist] of set | (city_list)
# http://api.openweathermap.org/data/2.5/weather?appid=c317c0f47833677543241449f9a3a454&units=metric&q=coetupo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {"city": citylist,"lat": lat,"lng":lng,"temp": temp,"humidity":humidity,"clouds":clouds,"winds":winds}
weather_data = pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#               city    lat     lng   temp  humidity  clouds  winds
# 0          teguise  29.06  -13.56  20.00        64      75   7.20
# 1           aykhal  65.95  111.51 -23.34        65      24   1.23
# 2            cervo -22.19  -46.24  28.00        69      40   3.10
# 3      grand gaube -20.01   57.66  27.70        83      40   4.10
# 4  arraial do cabo -22.97  -42.02  32.56        70      20   7.20
# 5           hasaki  35.73  140.83   8.13        81      75   2.60
# 6        jamestown -33.21  138.60  11.91        86      44   1.01
# 7            kapaa  22.08 -159.32  22.32        53      90   6.20
# 8           jieshi  22.82  115.83  18.21       100       0   0.71
# 9          lincoln  53.23   -0.54   7.55        93      20   1.50

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
